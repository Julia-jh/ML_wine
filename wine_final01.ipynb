# %% [markdown]
# # wine + soil + climate
# ## 데이터 정리 및 확인

# %% [markdown]
# ## 질문
# - 왜 lat이랑 lon을 int로 바꾸어 활용하는지
# - 소수점 아래 2자리까지, 총 4개 혹은 5개를 유효숫자로 활용하는 것 아니었는지
# - 음수에서 round를 활용하면 양수에 가까운 수로 변환되므로 -63.3가 -63이 아닌 -64가 된다
# - 혹시 병합과정에서 기준이 그랬다는 가정이라면 지리 정보 중 토양 or 기후 중 어떤 것을 기준으로 활용하게 되는지 궁금

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = None

# %%
folders = os.listdir('data')
folders
# Out:
# ['HadCRUT.5.0.2.0.analysis.summary_series.global.monthly.csv',
#  'HadCRUT.5.0.2.0.analysis.summary_series.global.monthly.nc',
#  'HWSD_가이드.pdf',
#  'ML_data_total.csv',
#  'soil_data_raw.zip',
#  'wine_soil_data_0719.csv',
#  'wine_soil_data_0721.csv',
#  'wine_total_data_0721.csv',
#  'wine_total_data_2025.csv',
#  'wine_total_data_2030.csv',
#  'wine_total_data_2035.csv',
#  'wine_total_data_2040.csv',
#  'wine_total_data_2041_2070.csv']

# %%
data =pd.DataFrame()
for files in os.listdir('data'):
    if files.startswith('wine_total_data'):
        print(files)
        df = pd.read_csv('data/' + files)
        data = pd.concat([data, df])
data.drop(['Unnamed: 0'], axis = 1, inplace = True)
# Out:
# wine_total_data_0721.csv
# wine_total_data_2025.csv
# wine_total_data_2030.csv
# wine_total_data_2035.csv
# wine_total_data_2040.csv
# wine_total_data_2041_2070.csv

# %%
data =pd.DataFrame()
dfList = []
for files in os.listdir('data'):
    if files.startswith('wine_total_data'):
        print(files)
        dfNM = 'df_{}'.format(files[-8:-4])
        dfList.append(dfNM)
        globals()[dfNM] = pd.read_csv('data/' + files)
        if 'Unnamed: 0' in globals()[dfNM].columns:
            globals()[dfNM].drop(['Unnamed: 0'], axis = 1, inplace = True)
        data = pd.concat([data, globals()[dfNM]])
# Out:
# wine_total_data_0721.csv
# wine_total_data_2025.csv
# wine_total_data_2030.csv
# wine_total_data_2035.csv
# wine_total_data_2040.csv
# wine_total_data_2041_2070.csv

# %%
globals()[dfList[-1]].rename(columns = {'year': 'Year'}, inplace = True)

# %%
for i in range(len(dfList)):
    print(len(globals()[dfList[i]].columns))
    print(globals()[dfList[i]].columns)
# Out:
# 67
# Index(['Longitude', 'Latitude', 'Soil Mapping Unit', 'Continent', 'Country',
#        'Region Lv1', 'Grape_Variety', 'SHARE_x', 'WRB4_x', 'KOPPEN',
#        'TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'BULK_DENSITY', 'DRAINAGE_x',
#        'ROOT_DEPTH_x', 'AWC_x', 'ROOTS_x', 'IL_x', 'HWSD2_SMU_ID_y',
#        'SEQUENCE', 'SHARE_y', 'WRB4_y', 'ROOT_DEPTH_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'COARSE', 'SAND', 'SILT', 'CLAY',
#        'TEXTURE_USDA_y', 'TEXTURE_SOTER', 'BULK', 'REF_BULK', 'ORG_CARBON',
#        'PH_WATER', 'TOTAL_N', 'CN_RATIO', 'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF',
#        'TEB', 'BSAT', 'ALUM_SAT', 'ESP', 'TCARBON_EQ', 'GYPSUM', 'ELEC_COND',
#        'Top12_Grape', 'LatRound', 'LngRound', 'LatInt', 'LngInt', 'lat', 'lon',
#        'TG', 'TN', 'TX', 'RR', 'RR1', 'Year', 'lat_round', 'lon_round',
#        'lat_int', 'lon_int'],
#       dtype='object')
# 65
# Index(['Longitude', 'Latitude', 'Soil Mapping Unit', 'Continent', 'Country',
#        'Region Lv1', 'Grape_Variety', 'SHARE_x', 'WRB4_x', 'KOPPEN',
#        'TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'BULK_DENSITY', 'DRAINAGE_x',
#        'ROOT_DEPTH_x', 'AWC_x', 'ROOTS_x', 'IL_x', 'HWSD2_SMU_ID_y',
#        'SEQUENCE', 'SHARE_y', 'WRB4_y', 'ROOT_DEPTH_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'COARSE', 'SAND', 'SILT', 'CLAY',
#        'TEXTURE_USDA_y', 'TEXTURE_SOTER', 'BULK', 'REF_BULK', 'ORG_CARBON',
#        'PH_WATER', 'TOTAL_N', 'CN_RATIO', 'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF',
#        'TEB', 'BSAT', 'ALUM_SAT', 'ESP', 'TCARBON_EQ', 'GYPSUM', 'ELEC_COND',
#        'Top12_Grape', 'LatRound', 'LngRound', 'LatInt', 'LngInt', 'lat', 'lon',
#        'TG', 'TN', 'TX', 'RR', 'RR1', 'Year', 'lat_int', 'lon_int'],
#       dtype='object')
# 65
# Index(['Longitude', 'Latitude', 'Soil Mapping Unit', 'Continent', 'Country',
#        'Region Lv1', 'Grape_Variety', 'SHARE_x', 'WRB4_x', 'KOPPEN',
#        'TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'BULK_DENSITY', 'DRAINAGE_x',
#        'ROOT_DEPTH_x', 'AWC_x', 'ROOTS_x', 'IL_x', 'HWSD2_SMU_ID_y',
#        'SEQUENCE', 'SHARE_y', 'WRB4_y', 'ROOT_DEPTH_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'COARSE', 'SAND', 'SILT', 'CLAY',
#        'TEXTURE_USDA_y', 'TEXTURE_SOTER', 'BULK', 'REF_BULK', 'ORG_CARBON',
#        'PH_WATER', 'TOTAL_N', 'CN_RATIO', 'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF',
#        'TEB', 'BSAT', 'ALUM_SAT', 'ESP', 'TCARBON_EQ', 'GYPSUM', 'ELEC_COND',
#        'Top12_Grape', 'LatRound', 'LngRound', 'LatInt', 'LngInt', 'lat', 'lon',
#        'TG', 'TN', 'TX', 'RR', 'RR1', 'Year', 'lat_int', 'lon_int'],
#       dtype='object')
# 65
# Index(['Longitude', 'Latitude', 'Soil Mapping Unit', 'Continent', 'Country',
#        'Region Lv1', 'Grape_Variety', 'SHARE_x', 'WRB4_x', 'KOPPEN',
#        'TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'BULK_DENSITY', 'DRAINAGE_x',
#        'ROOT_DEPTH_x', 'AWC_x', 'ROOTS_x', 'IL_x', 'HWSD2_SMU_ID_y',
#        'SEQUENCE', 'SHARE_y', 'WRB4_y', 'ROOT_DEPTH_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'COARSE', 'SAND', 'SILT', 'CLAY',
#        'TEXTURE_USDA_y', 'TEXTURE_SOTER', 'BULK', 'REF_BULK', 'ORG_CARBON',
#        'PH_WATER', 'TOTAL_N', 'CN_RATIO', 'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF',
#        'TEB', 'BSAT', 'ALUM_SAT', 'ESP', 'TCARBON_EQ', 'GYPSUM', 'ELEC_COND',
#        'Top12_Grape', 'LatRound', 'LngRound', 'LatInt', 'LngInt', 'lat', 'lon',
#        'TG', 'TN', 'TX', 'RR', 'RR1', 'Year', 'lat_int', 'lon_int'],
#       dtype='object')
# 65
# Index(['Longitude', 'Latitude', 'Soil Mapping Unit', 'Continent', 'Country',
#        'Region Lv1', 'Grape_Variety', 'SHARE_x', 'WRB4_x', 'KOPPEN',
#        'TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'BULK_DENSITY', 'DRAINAGE_x',
#        'ROOT_DEPTH_x', 'AWC_x', 'ROOTS_x', 'IL_x', 'HWSD2_SMU_ID_y',
#        'SEQUENCE', 'SHARE_y', 'WRB4_y', 'ROOT_DEPTH_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'COARSE', 'SAND', 'SILT', 'CLAY',
#        'TEXTURE_USDA_y', 'TEXTURE_SOTER', 'BULK', 'REF_BULK', 'ORG_CARBON',
#        'PH_WATER', 'TOTAL_N', 'CN_RATIO', 'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF',
#        'TEB', 'BSAT', 'ALUM_SAT', 'ESP', 'TCARBON_EQ', 'GYPSUM', 'ELEC_COND',
#        'Top12_Grape', 'LatRound', 'LngRound', 'LatInt', 'LngInt', 'lat', 'lon',
#        'TG', 'TN', 'TX', 'RR', 'RR1', 'Year', 'lat_int', 'lon_int'],
#       dtype='object')
# 65
# Index(['Longitude', 'Latitude', 'Soil Mapping Unit', 'Continent', 'Country',
#        'Region Lv1', 'Grape_Variety', 'SHARE_x', 'WRB4_x', 'KOPPEN',
#        'TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'BULK_DENSITY', 'DRAINAGE_x',
#        'ROOT_DEPTH_x', 'AWC_x', 'ROOTS_x', 'IL_x', 'HWSD2_SMU_ID_y',
#        'SEQUENCE', 'SHARE_y', 'WRB4_y', 'ROOT_DEPTH_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'COARSE', 'SAND', 'SILT', 'CLAY',
#        'TEXTURE_USDA_y', 'TEXTURE_SOTER', 'BULK', 'REF_BULK', 'ORG_CARBON',
#        'PH_WATER', 'TOTAL_N', 'CN_RATIO', 'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF',
#        'TEB', 'BSAT', 'ALUM_SAT', 'ESP', 'TCARBON_EQ', 'GYPSUM', 'ELEC_COND',
#        'Top12_Grape', 'LatRound', 'LngRound', 'LatInt', 'LngInt', 'Year',
#        'lat', 'lon', 'TG', 'TN', 'TX', 'RR', 'RR1', 'lat_int', 'lon_int'],
#       dtype='object')

# %%
globals()[dfList[0]]
# Out:
#        Longitude   Latitude  Soil Mapping Unit Continent    Country  \
# 0     -63.358333 -40.766667              12245  Americas  Argentina
# 1     -63.358333 -40.766667              12245  Americas  Argentina
# 2     -63.358333 -40.766667              12245  Americas  Argentina
# 3     -63.358333 -40.766667              12245  Americas  Argentina
# 4     -63.358333 -40.775000              12245  Americas  Argentina
# ...          ...        ...                ...       ...        ...
# 13817  16.483333  47.833333               9993    Europe    Hungary
# 13818  19.150000  46.391667               9768    Europe    Hungary
# 13819  19.150000  46.391667               9768    Europe    Hungary
# 13820  19.150000  46.391667               9768    Europe    Hungary
# 13821  19.150000  46.391667               9768    Europe    Hungary
#
#                Region Lv1 Grape_Variety  SHARE_x WRB4_x KOPPEN  \
# 0      Río Negro Province        malbec       60   FLeu      B
# 1      Río Negro Province        malbec       60   FLeu      B
# 2      Río Negro Province        malbec       60   FLeu      B
# 3      Río Negro Province        malbec       60   FLeu      B
# 4      Río Negro Province        malbec       60   FLeu      B
# ...                   ...           ...      ...    ...    ...
# 13817             Balaton   white blend       60   CHha      D
# 13818                Duna  kadarka blau       50   PHcc      D
# 13819                Duna  kadarka blau       50   PHcc      D
# 13820                Duna  kadarka blau       50   PHcc      D
# 13821                Duna  kadarka blau       50   PHcc      D
#
#        TEXTURE_USDA_x  REF_BULK_DENSITY  BULK_DENSITY DRAINAGE_x  \
# 0                11.0              1.69          1.50         MW
# 1                11.0              1.69          1.50         MW
# 2                11.0              1.69          1.50         MW
# 3                11.0              1.69          1.50         MW
# 4                11.0              1.69          1.50         MW
# ...               ...               ...           ...        ...
# 13817             9.0              1.75          1.29         MW
# 13818             9.0              1.80          1.33         MW
# 13819             9.0              1.80          1.33         MW
# 13820             9.0              1.80          1.33         MW
# 13821             9.0              1.80          1.33         MW
#
#        ROOT_DEPTH_x  AWC_x  ROOTS_x  IL_x  HWSD2_SMU_ID_y  SEQUENCE  SHARE_y  \
# 0                 1    142      NaN   NaN           12245         1       60
# 1                 1    142      NaN   NaN           12245         1       60
# 2                 1    142      NaN   NaN           12245         1       60
# 3                 1    142      NaN   NaN           12245         1       60
# 4                 1    142      NaN   NaN           12245         1       60
# ...             ...    ...      ...   ...             ...       ...      ...
# 13817             1    139      1.0   1.0            9993         1       60
# 13818             1    167      1.0   1.0            9768         1       50
# 13819             1    167      1.0   1.0            9768         1       50
# 13820             1    167      1.0   1.0            9768         1       50
# 13821             1    167      1.0   1.0            9768         1       50
#
#       WRB4_y  ROOT_DEPTH_y  ROOTS_y  IL_y  SWR DRAINAGE_y  AWC_y  COARSE  \
# 0       FLeu           1.0      NaN   NaN  NaN         MW  142.0       3
# 1       FLeu           1.0      NaN   NaN  NaN         MW  142.0       3
# 2       FLeu           1.0      NaN   NaN  NaN         MW  142.0       3
# 3       FLeu           1.0      NaN   NaN  NaN         MW  142.0       3
# 4       FLeu           1.0      NaN   NaN  NaN         MW  142.0       3
# ...      ...           ...      ...   ...  ...        ...    ...     ...
# 13817   CHha           1.0      1.0   1.0  1.0         MW  139.0      15
# 13818   PHcc           1.0      1.0   1.0  2.0         MW  167.0       3
# 13819   PHcc           1.0      1.0   1.0  2.0         MW  167.0       3
# 13820   PHcc           1.0      1.0   1.0  2.0         MW  167.0       3
# 13821   PHcc           1.0      1.0   1.0  2.0         MW  167.0       3
#
#        SAND  SILT  CLAY  TEXTURE_USDA_y TEXTURE_SOTER  BULK  REF_BULK  \
# 0        55    27    18            11.0             M  1.50      1.69
# 1        55    27    18            11.0             M  1.50      1.69
# 2        55    27    18            11.0             M  1.50      1.69
# 3        55    27    18            11.0             M  1.50      1.69
# 4        55    27    18            11.0             M  1.50      1.69
# ...     ...   ...   ...             ...           ...   ...       ...
# 13817    33    44    23             9.0             M  1.29      1.75
# 13818    40    34    26             9.0             M  1.33      1.80
# 13819    40    34    26             9.0             M  1.33      1.80
# 13820    40    34    26             9.0             M  1.33      1.80
# 13821    40    34    26             9.0             M  1.33      1.80
#
#        ORG_CARBON  PH_WATER  TOTAL_N  CN_RATIO  CEC_SOIL  CEC_CLAY  CEC_EFF  \
# 0           0.780       7.5     0.93         9        14        63       22
# 1           0.780       7.5     0.93         9        14        63       22
# 2           0.780       7.5     0.93         9        14        63       22
# 3           0.780       7.5     0.93         9        14        63       22
# 4           0.780       7.5     0.93         9        14        63       22
# ...           ...       ...      ...       ...       ...       ...      ...
# 13817       3.228       6.6     2.63        12        26        65       26
# 13818       1.876       7.6     1.87        10        19        53       31
# 13819       1.876       7.6     1.87        10        19        53       31
# 13820       1.876       7.6     1.87        10        19        53       31
# 13821       1.876       7.6     1.87        10        19        53       31
#
#        TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND  Top12_Grape  \
# 0       22    94         0    4         2.0     0.7          2            1
# 1       22    94         0    4         2.0     0.7          2            1
# 2       22    94         0    4         2.0     0.7          2            1
# 3       22    94         0    4         2.0     0.7          2            1
# 4       22    94         0    4         2.0     0.7          2            1
# ...    ...   ...       ...  ...         ...     ...        ...          ...
# 13817   26    93         0    1         0.0     0.8          1            0
# 13818   31    98         0    2        11.7     0.2          0            0
# 13819   31    98         0    2        11.7     0.2          0            0
# 13820   31    98         0    2        11.7     0.2          0            0
# 13821   31    98         0    2        11.7     0.2          0            0
#
#        LatRound  LngRound  LatInt  LngInt    lat    lon          TG  \
# 0         -41.0     -63.0     -40     -63 -40.75 -63.75  290.671964
# 1         -41.0     -63.0     -40     -63 -40.75 -63.25  290.655011
# 2         -41.0     -63.0     -40     -63 -40.25 -63.75  291.058975
# 3         -41.0     -63.0     -40     -63 -40.25 -63.25  290.893624
# 4         -41.0     -63.0     -40     -63 -40.75 -63.75  290.671964
# ...         ...       ...     ...     ...    ...    ...         ...
# 13817      48.0      16.0      47      16  47.75  16.75  288.641716
# 13818      46.0      19.0      46      19  46.25  19.25  289.334150
# 13819      46.0      19.0      46      19  46.25  19.75  289.495897
# 13820      46.0      19.0      46      19  46.75  19.25  289.209322
# 13821      46.0      19.0      46      19  46.75  19.75  289.230365
#
#               TN         TX         RR       RR1  Year  lat_round  lon_round  \
# 0      278.31567  303.50006  14.568954  1.333333  2021      -41.0      -64.0
# 1      278.43283  303.47107  15.902047  1.428571  2021      -41.0      -63.0
# 2      278.14188  304.67847  13.090754  1.285714  2021      -40.0      -64.0
# 3      278.20532  304.39062  17.103797  1.500000  2021      -40.0      -63.0
# 4      278.31567  303.50006  14.568954  1.333333  2021      -41.0      -64.0
# ...          ...        ...        ...       ...   ...        ...        ...
# 13817  271.34473  301.28100  27.442335  4.714286  2021       48.0       17.0
# 13818  270.87646  301.29350  24.005887  4.214286  2021       46.0       19.0
# 13819  271.16970  301.07513  22.787967  4.261905  2021       46.0       20.0
# 13820  270.88278  301.52680  22.684277  4.404762  2021       47.0       19.0
# 13821  270.95870  301.33798  21.953634  4.571429  2021       47.0       20.0
#
#        lat_int  lon_int
# 0          -40      -63
# 1          -40      -63
# 2          -40      -63
# 3          -40      -63
# 4          -40      -63
# ...        ...      ...
# 13817       47       16
# 13818       46       19
# 13819       46       19
# 13820       46       19
# 13821       46       19
#
# [13822 rows x 67 columns]

# %%
globals()[dfList[1]]
# Out:
#        Longitude   Latitude  Soil Mapping Unit Continent    Country  \
# 0     -63.358333 -40.766667              12245  Americas  Argentina
# 1     -63.358333 -40.766667              12245  Americas  Argentina
# 2     -63.358333 -40.766667              12245  Americas  Argentina
# 3     -63.358333 -40.766667              12245  Americas  Argentina
# 4     -63.358333 -40.775000              12245  Americas  Argentina
# ...          ...        ...                ...       ...        ...
# 13817  16.483333  47.833333               9993    Europe    Hungary
# 13818  19.150000  46.391667               9768    Europe    Hungary
# 13819  19.150000  46.391667               9768    Europe    Hungary
# 13820  19.150000  46.391667               9768    Europe    Hungary
# 13821  19.150000  46.391667               9768    Europe    Hungary
#
#                Region Lv1 Grape_Variety  SHARE_x WRB4_x KOPPEN  \
# 0      Río Negro Province        malbec       60   FLeu      B
# 1      Río Negro Province        malbec       60   FLeu      B
# 2      Río Negro Province        malbec       60   FLeu      B
# 3      Río Negro Province        malbec       60   FLeu      B
# 4      Río Negro Province        malbec       60   FLeu      B
# ...                   ...           ...      ...    ...    ...
# 13817             Balaton   white blend       60   CHha      D
# 13818                Duna  kadarka blau       50   PHcc      D
# 13819                Duna  kadarka blau       50   PHcc      D
# 13820                Duna  kadarka blau       50   PHcc      D
# 13821                Duna  kadarka blau       50   PHcc      D
#
#        TEXTURE_USDA_x  REF_BULK_DENSITY  BULK_DENSITY DRAINAGE_x  \
# 0                11.0              1.69          1.50         MW
# 1                11.0              1.69          1.50         MW
# 2                11.0              1.69          1.50         MW
# 3                11.0              1.69          1.50         MW
# 4                11.0              1.69          1.50         MW
# ...               ...               ...           ...        ...
# 13817             9.0              1.75          1.29         MW
# 13818             9.0              1.80          1.33         MW
# 13819             9.0              1.80          1.33         MW
# 13820             9.0              1.80          1.33         MW
# 13821             9.0              1.80          1.33         MW
#
#        ROOT_DEPTH_x  AWC_x  ROOTS_x  IL_x  HWSD2_SMU_ID_y  SEQUENCE  SHARE_y  \
# 0                 1    142      NaN   NaN           12245         1       60
# 1                 1    142      NaN   NaN           12245         1       60
# 2                 1    142      NaN   NaN           12245         1       60
# 3                 1    142      NaN   NaN           12245         1       60
# 4                 1    142      NaN   NaN           12245         1       60
# ...             ...    ...      ...   ...             ...       ...      ...
# 13817             1    139      1.0   1.0            9993         1       60
# 13818             1    167      1.0   1.0            9768         1       50
# 13819             1    167      1.0   1.0            9768         1       50
# 13820             1    167      1.0   1.0            9768         1       50
# 13821             1    167      1.0   1.0            9768         1       50
#
#       WRB4_y  ROOT_DEPTH_y  ROOTS_y  IL_y  SWR DRAINAGE_y  AWC_y  COARSE  \
# 0       FLeu           1.0      NaN   NaN  NaN         MW  142.0       3
# 1       FLeu           1.0      NaN   NaN  NaN         MW  142.0       3
# 2       FLeu           1.0      NaN   NaN  NaN         MW  142.0       3
# 3       FLeu           1.0      NaN   NaN  NaN         MW  142.0       3
# 4       FLeu           1.0      NaN   NaN  NaN         MW  142.0       3
# ...      ...           ...      ...   ...  ...        ...    ...     ...
# 13817   CHha           1.0      1.0   1.0  1.0         MW  139.0      15
# 13818   PHcc           1.0      1.0   1.0  2.0         MW  167.0       3
# 13819   PHcc           1.0      1.0   1.0  2.0         MW  167.0       3
# 13820   PHcc           1.0      1.0   1.0  2.0         MW  167.0       3
# 13821   PHcc           1.0      1.0   1.0  2.0         MW  167.0       3
#
#        SAND  SILT  CLAY  TEXTURE_USDA_y TEXTURE_SOTER  BULK  REF_BULK  \
# 0        55    27    18            11.0             M  1.50      1.69
# 1        55    27    18            11.0             M  1.50      1.69
# 2        55    27    18            11.0             M  1.50      1.69
# 3        55    27    18            11.0             M  1.50      1.69
# 4        55    27    18            11.0             M  1.50      1.69
# ...     ...   ...   ...             ...           ...   ...       ...
# 13817    33    44    23             9.0             M  1.29      1.75
# 13818    40    34    26             9.0             M  1.33      1.80
# 13819    40    34    26             9.0             M  1.33      1.80
# 13820    40    34    26             9.0             M  1.33      1.80
# 13821    40    34    26             9.0             M  1.33      1.80
#
#        ORG_CARBON  PH_WATER  TOTAL_N  CN_RATIO  CEC_SOIL  CEC_CLAY  CEC_EFF  \
# 0           0.780       7.5     0.93         9        14        63       22
# 1           0.780       7.5     0.93         9        14        63       22
# 2           0.780       7.5     0.93         9        14        63       22
# 3           0.780       7.5     0.93         9        14        63       22
# 4           0.780       7.5     0.93         9        14        63       22
# ...           ...       ...      ...       ...       ...       ...      ...
# 13817       3.228       6.6     2.63        12        26        65       26
# 13818       1.876       7.6     1.87        10        19        53       31
# 13819       1.876       7.6     1.87        10        19        53       31
# 13820       1.876       7.6     1.87        10        19        53       31
# 13821       1.876       7.6     1.87        10        19        53       31
#
#        TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND  Top12_Grape  \
# 0       22    94         0    4         2.0     0.7          2            1
# 1       22    94         0    4         2.0     0.7          2            1
# 2       22    94         0    4         2.0     0.7          2            1
# 3       22    94         0    4         2.0     0.7          2            1
# 4       22    94         0    4         2.0     0.7          2            1
# ...    ...   ...       ...  ...         ...     ...        ...          ...
# 13817   26    93         0    1         0.0     0.8          1            0
# 13818   31    98         0    2        11.7     0.2          0            0
# 13819   31    98         0    2        11.7     0.2          0            0
# 13820   31    98         0    2        11.7     0.2          0            0
# 13821   31    98         0    2        11.7     0.2          0            0
#
#        LatRound  LngRound  LatInt  LngInt    lat    lon          TG  \
# 0         -41.0     -63.0     -40     -63 -40.75 -63.75  291.832566
# 1         -41.0     -63.0     -40     -63 -40.75 -63.25  291.656100
# 2         -41.0     -63.0     -40     -63 -40.25 -63.75  292.434964
# 3         -41.0     -63.0     -40     -63 -40.25 -63.25  292.091389
# 4         -41.0     -63.0     -40     -63 -40.75 -63.75  291.832566
# ...         ...       ...     ...     ...    ...    ...         ...
# 13817      48.0      16.0      47      16  47.75  16.75  289.476911
# 13818      46.0      19.0      46      19  46.25  19.25  290.102650
# 13819      46.0      19.0      46      19  46.25  19.75  290.270926
# 13820      46.0      19.0      46      19  46.75  19.25  290.011614
# 13821      46.0      19.0      46      19  46.75  19.75  290.051800
#
#               TN         TX         RR       RR1  Year  lat_int  lon_int
# 0      281.10263  308.94640  12.711205  1.523810  2025      -40      -63
# 1      280.79290  308.32434  14.931194  1.571429  2025      -40      -63
# 2      281.20163  309.82962  10.477526  1.380952  2025      -40      -63
# 3      280.98373  308.99188  14.425991  1.523810  2025      -40      -63
# 4      281.10263  308.94640  12.711205  1.523810  2025      -40      -63
# ...          ...        ...        ...       ...   ...      ...      ...
# 13817  275.37970  302.11453  22.654244  4.452381  2025       47       16
# 13818  275.36865  302.94382  22.375926  4.428571  2025       46       19
# 13819  275.45715  302.57748  21.723447  4.380952  2025       46       19
# 13820  275.26254  302.80220  20.538277  4.785714  2025       46       19
# 13821  275.17500  302.58472  20.388095  4.952381  2025       46       19
#
# [13822 rows x 65 columns]

# %%
globals()[dfList[0]].columns
# Out:
# Index(['Longitude', 'Latitude', 'Soil Mapping Unit', 'Continent', 'Country',
#        'Region Lv1', 'Grape_Variety', 'SHARE_x', 'WRB4_x', 'KOPPEN',
#        'TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'BULK_DENSITY', 'DRAINAGE_x',
#        'ROOT_DEPTH_x', 'AWC_x', 'ROOTS_x', 'IL_x', 'HWSD2_SMU_ID_y',
#        'SEQUENCE', 'SHARE_y', 'WRB4_y', 'ROOT_DEPTH_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'COARSE', 'SAND', 'SILT', 'CLAY',
#        'TEXTURE_USDA_y', 'TEXTURE_SOTER', 'BULK', 'REF_BULK', 'ORG_CARBON',
#        'PH_WATER', 'TOTAL_N', 'CN_RATIO', 'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF',
#        'TEB', 'BSAT', 'ALUM_SAT', 'ESP', 'TCARBON_EQ', 'GYPSUM', 'ELEC_COND',
#        'Top12_Grape', 'LatRound', 'LngRound', 'LatInt', 'LngInt', 'lat', 'lon',
#        'TG', 'TN', 'TX', 'RR', 'RR1', 'Year', 'lat_round', 'lon_round',
#        'lat_int', 'lon_int'],
#       dtype='object')

# %%
globals()[dfList[0]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13822 entries, 0 to 13821
# Data columns (total 67 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Longitude          13822 non-null  float64
#  1   Latitude           13822 non-null  float64
#  2   Soil Mapping Unit  13822 non-null  int64
#  3   Continent          13822 non-null  object
#  4   Country            13822 non-null  object
#  5   Region Lv1         13760 non-null  object
#  6   Grape_Variety      13802 non-null  object
#  7   SHARE_x            13822 non-null  int64
#  8   WRB4_x             13822 non-null  object
#  9   KOPPEN             13822 non-null  object
#  10  TEXTURE_USDA_x     13416 non-null  float64
#  11  REF_BULK_DENSITY   13416 non-null  float64
#  12  BULK_DENSITY       13822 non-null  float64
#  13  DRAINAGE_x         13416 non-null  object
#  14  ROOT_DEPTH_x       13822 non-null  int64
#  15  AWC_x              13822 non-null  int64
#  16  ROOTS_x            6269 non-null   float64
#  17  IL_x               6269 non-null   float64
#  18  HWSD2_SMU_ID_y     13822 non-null  int64
#  19  SEQUENCE           13822 non-null  int64
#  20  SHARE_y            13822 non-null  int64
#  21  WRB4_y             13822 non-null  object
#  22  ROOT_DEPTH_y       13822 non-null  float64
#  23  ROOTS_y            6269 non-null   float64
#  24  IL_y               6269 non-null   float64
#  25  SWR                5185 non-null   float64
#  26  DRAINAGE_y         13416 non-null  object
#  27  AWC_y              13822 non-null  float64
#  28  COARSE             13822 non-null  int64
#  29  SAND               13822 non-null  int64
#  30  SILT               13822 non-null  int64
#  31  CLAY               13822 non-null  int64
#  32  TEXTURE_USDA_y     13416 non-null  float64
#  33  TEXTURE_SOTER      13822 non-null  object
#  34  BULK               13822 non-null  float64
#  35  REF_BULK           13416 non-null  float64
#  36  ORG_CARBON         13822 non-null  float64
#  37  PH_WATER           13822 non-null  float64
#  38  TOTAL_N            13822 non-null  float64
#  39  CN_RATIO           13822 non-null  int64
#  40  CEC_SOIL           13822 non-null  int64
#  41  CEC_CLAY           13822 non-null  int64
#  42  CEC_EFF            13822 non-null  int64
#  43  TEB                13822 non-null  int64
#  44  BSAT               13822 non-null  int64
#  45  ALUM_SAT           13822 non-null  int64
#  46  ESP                13822 non-null  int64
#  47  TCARBON_EQ         13822 non-null  float64
#  48  GYPSUM             13822 non-null  float64
#  49  ELEC_COND          13822 non-null  int64
#  50  Top12_Grape        13822 non-null  int64
#  51  LatRound           13822 non-null  float64
#  52  LngRound           13822 non-null  float64
#  53  LatInt             13822 non-null  int64
#  54  LngInt             13822 non-null  int64
#  55  lat                13822 non-null  float64
#  56  lon                13822 non-null  float64
#  57  TG                 13822 non-null  float64
#  58  TN                 13822 non-null  float64
#  59  TX                 13822 non-null  float64
#  60  RR                 13822 non-null  float64
#  61  RR1                13822 non-null  float64
#  62  Year               13822 non-null  int64
#  63  lat_round          13822 non-null  float64
#  64  lon_round          13822 non-null  float64
#  65  lat_int            13822 non-null  int64
#  66  lon_int            13822 non-null  int64
# dtypes: float64(31), int64(26), object(10)
# memory usage: 7.1+ MB

# %%
globals()[dfList[1]].columns
# Out:
# Index(['Longitude', 'Latitude', 'Soil Mapping Unit', 'Continent', 'Country',
#        'Region Lv1', 'Grape_Variety', 'SHARE_x', 'WRB4_x', 'KOPPEN',
#        'TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'BULK_DENSITY', 'DRAINAGE_x',
#        'ROOT_DEPTH_x', 'AWC_x', 'ROOTS_x', 'IL_x', 'HWSD2_SMU_ID_y',
#        'SEQUENCE', 'SHARE_y', 'WRB4_y', 'ROOT_DEPTH_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'COARSE', 'SAND', 'SILT', 'CLAY',
#        'TEXTURE_USDA_y', 'TEXTURE_SOTER', 'BULK', 'REF_BULK', 'ORG_CARBON',
#        'PH_WATER', 'TOTAL_N', 'CN_RATIO', 'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF',
#        'TEB', 'BSAT', 'ALUM_SAT', 'ESP', 'TCARBON_EQ', 'GYPSUM', 'ELEC_COND',
#        'Top12_Grape', 'LatRound', 'LngRound', 'LatInt', 'LngInt', 'lat', 'lon',
#        'TG', 'TN', 'TX', 'RR', 'RR1', 'Year', 'lat_int', 'lon_int'],
#       dtype='object')

# %%
data.head(10)
# Out:
#    Longitude   Latitude  Soil Mapping Unit Continent    Country  \
# 0 -63.358333 -40.766667              12245  Americas  Argentina
# 1 -63.358333 -40.766667              12245  Americas  Argentina
# 2 -63.358333 -40.766667              12245  Americas  Argentina
# 3 -63.358333 -40.766667              12245  Americas  Argentina
# 4 -63.358333 -40.775000              12245  Americas  Argentina
# 5 -63.358333 -40.775000              12245  Americas  Argentina
# 6 -63.358333 -40.775000              12245  Americas  Argentina
# 7 -63.358333 -40.775000              12245  Americas  Argentina
# 8 -67.641667 -39.066667              12325  Americas  Argentina
# 9 -67.641667 -39.066667              12325  Americas  Argentina
#
#            Region Lv1 Grape_Variety  SHARE_x WRB4_x KOPPEN  TEXTURE_USDA_x  \
# 0  Río Negro Province        malbec       60   FLeu      B            11.0
# 1  Río Negro Province        malbec       60   FLeu      B            11.0
# 2  Río Negro Province        malbec       60   FLeu      B            11.0
# 3  Río Negro Province        malbec       60   FLeu      B            11.0
# 4  Río Negro Province        malbec       60   FLeu      B            11.0
# 5  Río Negro Province        malbec       60   FLeu      B            11.0
# 6  Río Negro Province        malbec       60   FLeu      B            11.0
# 7  Río Negro Province        malbec       60   FLeu      B            11.0
# 8  Río Negro Province        malbec       50   RGeu      B            11.0
# 9  Río Negro Province        malbec       50   RGeu      B            11.0
#
#    REF_BULK_DENSITY  BULK_DENSITY DRAINAGE_x  ROOT_DEPTH_x  AWC_x  ROOTS_x  \
# 0              1.69          1.50         MW             1    142      NaN
# 1              1.69          1.50         MW             1    142      NaN
# 2              1.69          1.50         MW             1    142      NaN
# 3              1.69          1.50         MW             1    142      NaN
# 4              1.69          1.50         MW             1    142      NaN
# 5              1.69          1.50         MW             1    142      NaN
# 6              1.69          1.50         MW             1    142      NaN
# 7              1.69          1.50         MW             1    142      NaN
# 8              1.61          1.45         MW             1    106      NaN
# 9              1.61          1.45         MW             1    106      NaN
#
#    IL_x  HWSD2_SMU_ID_y  SEQUENCE  SHARE_y WRB4_y  ROOT_DEPTH_y  ROOTS_y  \
# 0   NaN           12245         1       60   FLeu           1.0      NaN
# 1   NaN           12245         1       60   FLeu           1.0      NaN
# 2   NaN           12245         1       60   FLeu           1.0      NaN
# 3   NaN           12245         1       60   FLeu           1.0      NaN
# 4   NaN           12245         1       60   FLeu           1.0      NaN
# 5   NaN           12245         1       60   FLeu           1.0      NaN
# 6   NaN           12245         1       60   FLeu           1.0      NaN
# 7   NaN           12245         1       60   FLeu           1.0      NaN
# 8   NaN           12325         1       50   RGeu           1.0      NaN
# 9   NaN           12325         1       50   RGeu           1.0      NaN
#
#    IL_y  SWR DRAINAGE_y  AWC_y  COARSE  SAND  SILT  CLAY  TEXTURE_USDA_y  \
# 0   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 1   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 2   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 3   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 4   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 5   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 6   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 7   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 8   NaN  NaN         MW  106.0      18    66    20    14            11.0
# 9   NaN  NaN         MW  106.0      18    66    20    14            11.0
#
#   TEXTURE_SOTER  BULK  REF_BULK  ORG_CARBON  PH_WATER  TOTAL_N  CN_RATIO  \
# 0             M  1.50      1.69       0.780       7.5     0.93         9
# 1             M  1.50      1.69       0.780       7.5     0.93         9
# 2             M  1.50      1.69       0.780       7.5     0.93         9
# 3             M  1.50      1.69       0.780       7.5     0.93         9
# 4             M  1.50      1.69       0.780       7.5     0.93         9
# 5             M  1.50      1.69       0.780       7.5     0.93         9
# 6             M  1.50      1.69       0.780       7.5     0.93         9
# 7             M  1.50      1.69       0.780       7.5     0.93         9
# 8             C  1.45      1.61       0.576       7.4     0.52        10
# 9             C  1.45      1.61       0.576       7.4     0.52        10
#
#    CEC_SOIL  CEC_CLAY  CEC_EFF  TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  \
# 0        14        63       22   22    94         0    4         2.0     0.7
# 1        14        63       22   22    94         0    4         2.0     0.7
# 2        14        63       22   22    94         0    4         2.0     0.7
# 3        14        63       22   22    94         0    4         2.0     0.7
# 4        14        63       22   22    94         0    4         2.0     0.7
# 5        14        63       22   22    94         0    4         2.0     0.7
# 6        14        63       22   22    94         0    4         2.0     0.7
# 7        14        63       22   22    94         0    4         2.0     0.7
# 8        13        75       20   20    98         0    3         1.8     4.0
# 9        13        75       20   20    98         0    3         1.8     4.0
#
#    ELEC_COND  Top12_Grape  LatRound  LngRound  LatInt  LngInt    lat    lon  \
# 0          2            1     -41.0     -63.0     -40     -63 -40.75 -63.75
# 1          2            1     -41.0     -63.0     -40     -63 -40.75 -63.25
# 2          2            1     -41.0     -63.0     -40     -63 -40.25 -63.75
# 3          2            1     -41.0     -63.0     -40     -63 -40.25 -63.25
# 4          2            1     -41.0     -63.0     -40     -63 -40.75 -63.75
# 5          2            1     -41.0     -63.0     -40     -63 -40.75 -63.25
# 6          2            1     -41.0     -63.0     -40     -63 -40.25 -63.75
# 7          2            1     -41.0     -63.0     -40     -63 -40.25 -63.25
# 8          1            1     -39.0     -68.0     -39     -67 -39.75 -67.75
# 9          1            1     -39.0     -68.0     -39     -67 -39.75 -67.25
#
#            TG         TN         TX         RR       RR1    Year  lat_round  \
# 0  290.671964  278.31567  303.50006  14.568954  1.333333  2021.0      -41.0
# 1  290.655011  278.43283  303.47107  15.902047  1.428571  2021.0      -41.0
# 2  291.058975  278.14188  304.67847  13.090754  1.285714  2021.0      -40.0
# 3  290.893624  278.20532  304.39062  17.103797  1.500000  2021.0      -40.0
# 4  290.671964  278.31567  303.50006  14.568954  1.333333  2021.0      -41.0
# 5  290.655011  278.43283  303.47107  15.902047  1.428571  2021.0      -41.0
# 6  291.058975  278.14188  304.67847  13.090754  1.285714  2021.0      -40.0
# 7  290.893624  278.20532  304.39062  17.103797  1.500000  2021.0      -40.0
# 8  290.195117  276.20862  305.40012   6.301529  1.595238  2021.0      -40.0
# 9  290.753680  276.69360  305.49658   7.125111  1.452381  2021.0      -40.0
#
#    lon_round  lat_int  lon_int  year
# 0      -64.0      -40      -63   NaN
# 1      -63.0      -40      -63   NaN
# 2      -64.0      -40      -63   NaN
# 3      -63.0      -40      -63   NaN
# 4      -64.0      -40      -63   NaN
# 5      -63.0      -40      -63   NaN
# 6      -64.0      -40      -63   NaN
# 7      -63.0      -40      -63   NaN
# 8      -68.0      -39      -67   NaN
# 9      -67.0      -39      -67   NaN

# %%
print(data.columns)
print(len(data.columns))
# Out:
# Index(['Longitude', 'Latitude', 'Soil Mapping Unit', 'Continent', 'Country',
#        'Region Lv1', 'Grape_Variety', 'SHARE_x', 'WRB4_x', 'KOPPEN',
#        'TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'BULK_DENSITY', 'DRAINAGE_x',
#        'ROOT_DEPTH_x', 'AWC_x', 'ROOTS_x', 'IL_x', 'HWSD2_SMU_ID_y',
#        'SEQUENCE', 'SHARE_y', 'WRB4_y', 'ROOT_DEPTH_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'COARSE', 'SAND', 'SILT', 'CLAY',
#        'TEXTURE_USDA_y', 'TEXTURE_SOTER', 'BULK', 'REF_BULK', 'ORG_CARBON',
#        'PH_WATER', 'TOTAL_N', 'CN_RATIO', 'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF',
#        'TEB', 'BSAT', 'ALUM_SAT', 'ESP', 'TCARBON_EQ', 'GYPSUM', 'ELEC_COND',
#        'Top12_Grape', 'LatRound', 'LngRound', 'LatInt', 'LngInt', 'lat', 'lon',
#        'TG', 'TN', 'TX', 'RR', 'RR1', 'Year', 'lat_round', 'lon_round',
#        'lat_int', 'lon_int', 'year'],
#       dtype='object')
# 68

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152042 entries, 0 to 82931
# Data columns (total 68 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Longitude          152042 non-null  float64
#  1   Latitude           152042 non-null  float64
#  2   Soil Mapping Unit  152042 non-null  int64
#  3   Continent          152042 non-null  object
#  4   Country            152042 non-null  object
#  5   Region Lv1         151360 non-null  object
#  6   Grape_Variety      151822 non-null  object
#  7   SHARE_x            152042 non-null  int64
#  8   WRB4_x             152042 non-null  object
#  9   KOPPEN             152042 non-null  object
#  10  TEXTURE_USDA_x     147576 non-null  float64
#  11  REF_BULK_DENSITY   147576 non-null  float64
#  12  BULK_DENSITY       152042 non-null  float64
#  13  DRAINAGE_x         147576 non-null  object
#  14  ROOT_DEPTH_x       152042 non-null  int64
#  15  AWC_x              152042 non-null  int64
#  16  ROOTS_x            68959 non-null   float64
#  17  IL_x               68959 non-null   float64
#  18  HWSD2_SMU_ID_y     152042 non-null  int64
#  19  SEQUENCE           152042 non-null  int64
#  20  SHARE_y            152042 non-null  int64
#  21  WRB4_y             152042 non-null  object
#  22  ROOT_DEPTH_y       152042 non-null  float64
#  23  ROOTS_y            68959 non-null   float64
#  24  IL_y               68959 non-null   float64
#  25  SWR                57035 non-null   float64
#  26  DRAINAGE_y         147576 non-null  object
#  27  AWC_y              152042 non-null  float64
#  28  COARSE             152042 non-null  int64
#  29  SAND               152042 non-null  int64
#  30  SILT               152042 non-null  int64
#  31  CLAY               152042 non-null  int64
#  32  TEXTURE_USDA_y     147576 non-null  float64
#  33  TEXTURE_SOTER      152042 non-null  object
#  34  BULK               152042 non-null  float64
#  35  REF_BULK           147576 non-null  float64
#  36  ORG_CARBON         152042 non-null  float64
#  37  PH_WATER           152042 non-null  float64
#  38  TOTAL_N            152042 non-null  float64
#  39  CN_RATIO           152042 non-null  int64
#  40  CEC_SOIL           152042 non-null  int64
#  41  CEC_CLAY           152042 non-null  int64
#  42  CEC_EFF            152042 non-null  int64
#  43  TEB                152042 non-null  int64
#  44  BSAT               152042 non-null  int64
#  45  ALUM_SAT           152042 non-null  int64
#  46  ESP                152042 non-null  int64
#  47  TCARBON_EQ         152042 non-null  float64
#  48  GYPSUM             152042 non-null  float64
#  49  ELEC_COND          152042 non-null  int64
#  50  Top12_Grape        152042 non-null  int64
#  51  LatRound           152042 non-null  float64
#  52  LngRound           152042 non-null  float64
#  53  LatInt             152042 non-null  int64
#  54  LngInt             152042 non-null  int64
#  55  lat                152042 non-null  float64
#  56  lon                152042 non-null  float64
#  57  TG                 152042 non-null  float64
#  58  TN                 152042 non-null  float64
#  59  TX                 152042 non-null  float64
#  60  RR                 152042 non-null  float64
#  61  RR1                152042 non-null  float64
#  62  Year               69110 non-null   float64
#  63  lat_round          13822 non-null   float64
#  64  lon_round          13822 non-null   float64
#  65  lat_int            152042 non-null  int64
#  66  lon_int            152042 non-null  int64
#  67  year               82932 non-null   float64
# dtypes: float64(33), int64(25), object(10)
# memory usage: 80.0+ MB

# %%
globals()[dfList[0]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13822 entries, 0 to 13821
# Data columns (total 67 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Longitude          13822 non-null  float64
#  1   Latitude           13822 non-null  float64
#  2   Soil Mapping Unit  13822 non-null  int64
#  3   Continent          13822 non-null  object
#  4   Country            13822 non-null  object
#  5   Region Lv1         13760 non-null  object
#  6   Grape_Variety      13802 non-null  object
#  7   SHARE_x            13822 non-null  int64
#  8   WRB4_x             13822 non-null  object
#  9   KOPPEN             13822 non-null  object
#  10  TEXTURE_USDA_x     13416 non-null  float64
#  11  REF_BULK_DENSITY   13416 non-null  float64
#  12  BULK_DENSITY       13822 non-null  float64
#  13  DRAINAGE_x         13416 non-null  object
#  14  ROOT_DEPTH_x       13822 non-null  int64
#  15  AWC_x              13822 non-null  int64
#  16  ROOTS_x            6269 non-null   float64
#  17  IL_x               6269 non-null   float64
#  18  HWSD2_SMU_ID_y     13822 non-null  int64
#  19  SEQUENCE           13822 non-null  int64
#  20  SHARE_y            13822 non-null  int64
#  21  WRB4_y             13822 non-null  object
#  22  ROOT_DEPTH_y       13822 non-null  float64
#  23  ROOTS_y            6269 non-null   float64
#  24  IL_y               6269 non-null   float64
#  25  SWR                5185 non-null   float64
#  26  DRAINAGE_y         13416 non-null  object
#  27  AWC_y              13822 non-null  float64
#  28  COARSE             13822 non-null  int64
#  29  SAND               13822 non-null  int64
#  30  SILT               13822 non-null  int64
#  31  CLAY               13822 non-null  int64
#  32  TEXTURE_USDA_y     13416 non-null  float64
#  33  TEXTURE_SOTER      13822 non-null  object
#  34  BULK               13822 non-null  float64
#  35  REF_BULK           13416 non-null  float64
#  36  ORG_CARBON         13822 non-null  float64
#  37  PH_WATER           13822 non-null  float64
#  38  TOTAL_N            13822 non-null  float64
#  39  CN_RATIO           13822 non-null  int64
#  40  CEC_SOIL           13822 non-null  int64
#  41  CEC_CLAY           13822 non-null  int64
#  42  CEC_EFF            13822 non-null  int64
#  43  TEB                13822 non-null  int64
#  44  BSAT               13822 non-null  int64
#  45  ALUM_SAT           13822 non-null  int64
#  46  ESP                13822 non-null  int64
#  47  TCARBON_EQ         13822 non-null  float64
#  48  GYPSUM             13822 non-null  float64
#  49  ELEC_COND          13822 non-null  int64
#  50  Top12_Grape        13822 non-null  int64
#  51  LatRound           13822 non-null  float64
#  52  LngRound           13822 non-null  float64
#  53  LatInt             13822 non-null  int64
#  54  LngInt             13822 non-null  int64
#  55  lat                13822 non-null  float64
#  56  lon                13822 non-null  float64
#  57  TG                 13822 non-null  float64
#  58  TN                 13822 non-null  float64
#  59  TX                 13822 non-null  float64
#  60  RR                 13822 non-null  float64
#  61  RR1                13822 non-null  float64
#  62  Year               13822 non-null  int64
#  63  lat_round          13822 non-null  float64
#  64  lon_round          13822 non-null  float64
#  65  lat_int            13822 non-null  int64
#  66  lon_int            13822 non-null  int64
# dtypes: float64(31), int64(26), object(10)
# memory usage: 7.1+ MB

# %%
globals()[dfList[0]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13822 entries, 0 to 13821
# Data columns (total 67 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Longitude          13822 non-null  float64
#  1   Latitude           13822 non-null  float64
#  2   Soil Mapping Unit  13822 non-null  int64
#  3   Continent          13822 non-null  object
#  4   Country            13822 non-null  object
#  5   Region Lv1         13760 non-null  object
#  6   Grape_Variety      13802 non-null  object
#  7   SHARE_x            13822 non-null  int64
#  8   WRB4_x             13822 non-null  object
#  9   KOPPEN             13822 non-null  object
#  10  TEXTURE_USDA_x     13416 non-null  float64
#  11  REF_BULK_DENSITY   13416 non-null  float64
#  12  BULK_DENSITY       13822 non-null  float64
#  13  DRAINAGE_x         13416 non-null  object
#  14  ROOT_DEPTH_x       13822 non-null  int64
#  15  AWC_x              13822 non-null  int64
#  16  ROOTS_x            6269 non-null   float64
#  17  IL_x               6269 non-null   float64
#  18  HWSD2_SMU_ID_y     13822 non-null  int64
#  19  SEQUENCE           13822 non-null  int64
#  20  SHARE_y            13822 non-null  int64
#  21  WRB4_y             13822 non-null  object
#  22  ROOT_DEPTH_y       13822 non-null  float64
#  23  ROOTS_y            6269 non-null   float64
#  24  IL_y               6269 non-null   float64
#  25  SWR                5185 non-null   float64
#  26  DRAINAGE_y         13416 non-null  object
#  27  AWC_y              13822 non-null  float64
#  28  COARSE             13822 non-null  int64
#  29  SAND               13822 non-null  int64
#  30  SILT               13822 non-null  int64
#  31  CLAY               13822 non-null  int64
#  32  TEXTURE_USDA_y     13416 non-null  float64
#  33  TEXTURE_SOTER      13822 non-null  object
#  34  BULK               13822 non-null  float64
#  35  REF_BULK           13416 non-null  float64
#  36  ORG_CARBON         13822 non-null  float64
#  37  PH_WATER           13822 non-null  float64
#  38  TOTAL_N            13822 non-null  float64
#  39  CN_RATIO           13822 non-null  int64
#  40  CEC_SOIL           13822 non-null  int64
#  41  CEC_CLAY           13822 non-null  int64
#  42  CEC_EFF            13822 non-null  int64
#  43  TEB                13822 non-null  int64
#  44  BSAT               13822 non-null  int64
#  45  ALUM_SAT           13822 non-null  int64
#  46  ESP                13822 non-null  int64
#  47  TCARBON_EQ         13822 non-null  float64
#  48  GYPSUM             13822 non-null  float64
#  49  ELEC_COND          13822 non-null  int64
#  50  Top12_Grape        13822 non-null  int64
#  51  LatRound           13822 non-null  float64
#  52  LngRound           13822 non-null  float64
#  53  LatInt             13822 non-null  int64
#  54  LngInt             13822 non-null  int64
#  55  lat                13822 non-null  float64
#  56  lon                13822 non-null  float64
#  57  TG                 13822 non-null  float64
#  58  TN                 13822 non-null  float64
#  59  TX                 13822 non-null  float64
#  60  RR                 13822 non-null  float64
#  61  RR1                13822 non-null  float64
#  62  Year               13822 non-null  int64
#  63  lat_round          13822 non-null  float64
#  64  lon_round          13822 non-null  float64
#  65  lat_int            13822 non-null  int64
#  66  lon_int            13822 non-null  int64
# dtypes: float64(31), int64(26), object(10)
# memory usage: 7.1+ MB

# %% [markdown]
# ## clensing & encoding
# - wine_data_EDA2.ipynb: 이 파일에서 “결측치 처리” 파트까지 진행해주시면 되고,
# - Machine_Learning_total.ipynb: 이 파일에서 ~ one-hot encoding 까지 적용 후, SVM이나 다른 머신러닝 진행하면서 사용하셨던 StandardScaler까지 적용해주시면 될 것 같습니다!
# - 혹시 가능하시다면 25년 ~ 70년까지 한 파일로 정리 부탁드립니다 ㅎㅎ

# %% [markdown]
# ### Wine_data_EDA2
# #### 포도 품종 정리하기

# %% [markdown]
# ##### 25년~70년 Data 합치기

# %%
data = pd.DataFrame()
dfList = []
for files in os.listdir('data'):
    if files.startswith('wine_total_data_2'):
        print(files)
        dfNM = 'df_{}'.format(files[-8:-4])
        dfList.append(dfNM)
        globals()[dfNM] = pd.read_csv('data/' + files)
        globals()[dfNM].drop(['Unnamed: 0'], axis = 1, inplace = True)
        data = pd.concat([data, globals()[dfNM]])
# Out:
# wine_total_data_2025.csv
# wine_total_data_2030.csv
# wine_total_data_2035.csv
# wine_total_data_2040.csv
# wine_total_data_2041_2070.csv

# %%
LEN = 0
for i in range(len(dfList)):
    LEN += len(globals()[dfList[i]])
if LEN == len(data):
    print(LEN, len(data))
    print('Data 합치기 완료')
# Out:
# 138220 138220
# Data 합치기 완료

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 138220 entries, 0 to 82931
# Data columns (total 66 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Longitude          138220 non-null  float64
#  1   Latitude           138220 non-null  float64
#  2   Soil Mapping Unit  138220 non-null  int64
#  3   Continent          138220 non-null  object
#  4   Country            138220 non-null  object
#  5   Region Lv1         137600 non-null  object
#  6   Grape_Variety      138020 non-null  object
#  7   SHARE_x            138220 non-null  int64
#  8   WRB4_x             138220 non-null  object
#  9   KOPPEN             138220 non-null  object
#  10  TEXTURE_USDA_x     134160 non-null  float64
#  11  REF_BULK_DENSITY   134160 non-null  float64
#  12  BULK_DENSITY       138220 non-null  float64
#  13  DRAINAGE_x         134160 non-null  object
#  14  ROOT_DEPTH_x       138220 non-null  int64
#  15  AWC_x              138220 non-null  int64
#  16  ROOTS_x            62690 non-null   float64
#  17  IL_x               62690 non-null   float64
#  18  HWSD2_SMU_ID_y     138220 non-null  int64
#  19  SEQUENCE           138220 non-null  int64
#  20  SHARE_y            138220 non-null  int64
#  21  WRB4_y             138220 non-null  object
#  22  ROOT_DEPTH_y       138220 non-null  float64
#  23  ROOTS_y            62690 non-null   float64
#  24  IL_y               62690 non-null   float64
#  25  SWR                51850 non-null   float64
#  26  DRAINAGE_y         134160 non-null  object
#  27  AWC_y              138220 non-null  float64
#  28  COARSE             138220 non-null  int64
#  29  SAND               138220 non-null  int64
#  30  SILT               138220 non-null  int64
#  31  CLAY               138220 non-null  int64
#  32  TEXTURE_USDA_y     134160 non-null  float64
#  33  TEXTURE_SOTER      138220 non-null  object
#  34  BULK               138220 non-null  float64
#  35  REF_BULK           134160 non-null  float64
#  36  ORG_CARBON         138220 non-null  float64
#  37  PH_WATER           138220 non-null  float64
#  38  TOTAL_N            138220 non-null  float64
#  39  CN_RATIO           138220 non-null  int64
#  40  CEC_SOIL           138220 non-null  int64
#  41  CEC_CLAY           138220 non-null  int64
#  42  CEC_EFF            138220 non-null  int64
#  43  TEB                138220 non-null  int64
#  44  BSAT               138220 non-null  int64
#  45  ALUM_SAT           138220 non-null  int64
#  46  ESP                138220 non-null  int64
#  47  TCARBON_EQ         138220 non-null  float64
#  48  GYPSUM             138220 non-null  float64
#  49  ELEC_COND          138220 non-null  int64
#  50  Top12_Grape        138220 non-null  int64
#  51  LatRound           138220 non-null  float64
#  52  LngRound           138220 non-null  float64
#  53  LatInt             138220 non-null  int64
#  54  LngInt             138220 non-null  int64
#  55  lat                138220 non-null  float64
#  56  lon                138220 non-null  float64
#  57  TG                 138220 non-null  float64
#  58  TN                 138220 non-null  float64
#  59  TX                 138220 non-null  float64
#  60  RR                 138220 non-null  float64
#  61  RR1                138220 non-null  float64
#  62  Year               55288 non-null   float64
#  63  lat_int            138220 non-null  int64
#  64  lon_int            138220 non-null  int64
#  65  year               82932 non-null   float64
# dtypes: float64(31), int64(25), object(10)
# memory usage: 70.7+ MB

# %%
A = len(data)
B = data['Year'].notnull().sum()
C = data['year'].notnull().sum()

if A == (B + C):
    print('RENAME')
else:
    print(A, B, C, B-C)
# Out:
# RENAME

# %%
data = pd.DataFrame()
dfList = []
for files in os.listdir('data'):
    if files.startswith('wine_total_data_2'):
        print(files)
        dfNM = 'df_{}'.format(files[-8:-4])
        dfList.append(dfNM)
        globals()[dfNM] = pd.read_csv('data/' + files)
        globals()[dfNM].drop(['Unnamed: 0'], axis = 1, inplace = True)
        
        if 'year' in globals()[dfNM].columns:
            globals()[dfNM].rename(columns = {'year': 'Year'}, inplace = True)
        data = pd.concat([data, globals()[dfNM]])
# Out:
# wine_total_data_2025.csv
# wine_total_data_2030.csv
# wine_total_data_2035.csv
# wine_total_data_2040.csv
# wine_total_data_2041_2070.csv

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 138220 entries, 0 to 82931
# Data columns (total 65 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Longitude          138220 non-null  float64
#  1   Latitude           138220 non-null  float64
#  2   Soil Mapping Unit  138220 non-null  int64
#  3   Continent          138220 non-null  object
#  4   Country            138220 non-null  object
#  5   Region Lv1         137600 non-null  object
#  6   Grape_Variety      138020 non-null  object
#  7   SHARE_x            138220 non-null  int64
#  8   WRB4_x             138220 non-null  object
#  9   KOPPEN             138220 non-null  object
#  10  TEXTURE_USDA_x     134160 non-null  float64
#  11  REF_BULK_DENSITY   134160 non-null  float64
#  12  BULK_DENSITY       138220 non-null  float64
#  13  DRAINAGE_x         134160 non-null  object
#  14  ROOT_DEPTH_x       138220 non-null  int64
#  15  AWC_x              138220 non-null  int64
#  16  ROOTS_x            62690 non-null   float64
#  17  IL_x               62690 non-null   float64
#  18  HWSD2_SMU_ID_y     138220 non-null  int64
#  19  SEQUENCE           138220 non-null  int64
#  20  SHARE_y            138220 non-null  int64
#  21  WRB4_y             138220 non-null  object
#  22  ROOT_DEPTH_y       138220 non-null  float64
#  23  ROOTS_y            62690 non-null   float64
#  24  IL_y               62690 non-null   float64
#  25  SWR                51850 non-null   float64
#  26  DRAINAGE_y         134160 non-null  object
#  27  AWC_y              138220 non-null  float64
#  28  COARSE             138220 non-null  int64
#  29  SAND               138220 non-null  int64
#  30  SILT               138220 non-null  int64
#  31  CLAY               138220 non-null  int64
#  32  TEXTURE_USDA_y     134160 non-null  float64
#  33  TEXTURE_SOTER      138220 non-null  object
#  34  BULK               138220 non-null  float64
#  35  REF_BULK           134160 non-null  float64
#  36  ORG_CARBON         138220 non-null  float64
#  37  PH_WATER           138220 non-null  float64
#  38  TOTAL_N            138220 non-null  float64
#  39  CN_RATIO           138220 non-null  int64
#  40  CEC_SOIL           138220 non-null  int64
#  41  CEC_CLAY           138220 non-null  int64
#  42  CEC_EFF            138220 non-null  int64
#  43  TEB                138220 non-null  int64
#  44  BSAT               138220 non-null  int64
#  45  ALUM_SAT           138220 non-null  int64
#  46  ESP                138220 non-null  int64
#  47  TCARBON_EQ         138220 non-null  float64
#  48  GYPSUM             138220 non-null  float64
#  49  ELEC_COND          138220 non-null  int64
#  50  Top12_Grape        138220 non-null  int64
#  51  LatRound           138220 non-null  float64
#  52  LngRound           138220 non-null  float64
#  53  LatInt             138220 non-null  int64
#  54  LngInt             138220 non-null  int64
#  55  lat                138220 non-null  float64
#  56  lon                138220 non-null  float64
#  57  TG                 138220 non-null  float64
#  58  TN                 138220 non-null  float64
#  59  TX                 138220 non-null  float64
#  60  RR                 138220 non-null  float64
#  61  RR1                138220 non-null  float64
#  62  Year               138220 non-null  int64
#  63  lat_int            138220 non-null  int64
#  64  lon_int            138220 non-null  int64
# dtypes: float64(29), int64(26), object(10)
# memory usage: 69.6+ MB

# %%
if 'year' not in data.columns:
    print(data['Year'].unique())
# Out:
# [2025 2030 2035 2040 2045 2050 2055 2060 2065 2070]

# %%
data.head()
# Out:
#    Longitude   Latitude  Soil Mapping Unit Continent    Country  \
# 0 -63.358333 -40.766667              12245  Americas  Argentina
# 1 -63.358333 -40.766667              12245  Americas  Argentina
# 2 -63.358333 -40.766667              12245  Americas  Argentina
# 3 -63.358333 -40.766667              12245  Americas  Argentina
# 4 -63.358333 -40.775000              12245  Americas  Argentina
#
#            Region Lv1 Grape_Variety  SHARE_x WRB4_x KOPPEN  TEXTURE_USDA_x  \
# 0  Río Negro Province        malbec       60   FLeu      B            11.0
# 1  Río Negro Province        malbec       60   FLeu      B            11.0
# 2  Río Negro Province        malbec       60   FLeu      B            11.0
# 3  Río Negro Province        malbec       60   FLeu      B            11.0
# 4  Río Negro Province        malbec       60   FLeu      B            11.0
#
#    REF_BULK_DENSITY  BULK_DENSITY DRAINAGE_x  ROOT_DEPTH_x  AWC_x  ROOTS_x  \
# 0              1.69           1.5         MW             1    142      NaN
# 1              1.69           1.5         MW             1    142      NaN
# 2              1.69           1.5         MW             1    142      NaN
# 3              1.69           1.5         MW             1    142      NaN
# 4              1.69           1.5         MW             1    142      NaN
#
#    IL_x  HWSD2_SMU_ID_y  SEQUENCE  SHARE_y WRB4_y  ROOT_DEPTH_y  ROOTS_y  \
# 0   NaN           12245         1       60   FLeu           1.0      NaN
# 1   NaN           12245         1       60   FLeu           1.0      NaN
# 2   NaN           12245         1       60   FLeu           1.0      NaN
# 3   NaN           12245         1       60   FLeu           1.0      NaN
# 4   NaN           12245         1       60   FLeu           1.0      NaN
#
#    IL_y  SWR DRAINAGE_y  AWC_y  COARSE  SAND  SILT  CLAY  TEXTURE_USDA_y  \
# 0   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 1   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 2   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 3   NaN  NaN         MW  142.0       3    55    27    18            11.0
# 4   NaN  NaN         MW  142.0       3    55    27    18            11.0
#
#   TEXTURE_SOTER  BULK  REF_BULK  ORG_CARBON  PH_WATER  TOTAL_N  CN_RATIO  \
# 0             M   1.5      1.69        0.78       7.5     0.93         9
# 1             M   1.5      1.69        0.78       7.5     0.93         9
# 2             M   1.5      1.69        0.78       7.5     0.93         9
# 3             M   1.5      1.69        0.78       7.5     0.93         9
# 4             M   1.5      1.69        0.78       7.5     0.93         9
#
#    CEC_SOIL  CEC_CLAY  CEC_EFF  TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  \
# 0        14        63       22   22    94         0    4         2.0     0.7
# 1        14        63       22   22    94         0    4         2.0     0.7
# 2        14        63       22   22    94         0    4         2.0     0.7
# 3        14        63       22   22    94         0    4         2.0     0.7
# 4        14        63       22   22    94         0    4         2.0     0.7
#
#    ELEC_COND  Top12_Grape  LatRound  LngRound  LatInt  LngInt    lat    lon  \
# 0          2            1     -41.0     -63.0     -40     -63 -40.75 -63.75
# 1          2            1     -41.0     -63.0     -40     -63 -40.75 -63.25
# 2          2            1     -41.0     -63.0     -40     -63 -40.25 -63.75
# 3          2            1     -41.0     -63.0     -40     -63 -40.25 -63.25
# 4          2            1     -41.0     -63.0     -40     -63 -40.75 -63.75
#
#            TG         TN         TX         RR       RR1  Year  lat_int  \
# 0  291.832566  281.10263  308.94640  12.711205  1.523810  2025      -40
# 1  291.656100  280.79290  308.32434  14.931194  1.571429  2025      -40
# 2  292.434964  281.20163  309.82962  10.477526  1.380952  2025      -40
# 3  292.091389  280.98373  308.99188  14.425991  1.523810  2025      -40
# 4  291.832566  281.10263  308.94640  12.711205  1.523810  2025      -40
#
#    lon_int
# 0      -63
# 1      -63
# 2      -63
# 3      -63
# 4      -63

# %%
data['Grape_Variety'] = data['Grape_Variety'].str.strip()
len(data['Grape_Variety'].unique())
# Out:
# 187

# %%
grapes = [grape for grape in data.loc[~data['Grape_Variety'].isna(), 'Grape_Variety'].unique()]
grapes = sorted(grapes)
grapes
# Out:
# ['aglianico',
#  'albarin negro',
#  'albarin negro mencia',
#  'albarossa',
#  'albillo criolo',
#  'aleatico',
#  'alfrocheiro preto',
#  'alicante bouschet',
#  'aligote',
#  'aragonez',
#  'areni noir',
#  'assyrtiko',
#  'baga',
#  'barbera',
#  'bastardo',
#  'bical',
#  'blatina',
#  'blaufrankisch',
#  'bobal',
#  'bonarda',
#  'bordeaux blend red',
#  'bourboulenc',
#  'brachetto',
#  'brandy',
#  'cabernet',
#  'cabernet franc',
#  'cabernet sauvignon',
#  'cabernet savignon',
#  'callet',
#  'cardin',
#  'carignan',
#  'carignan gris',
#  'carinena',
#  'carmenere',
#  'carrasquin',
#  'chambourcin',
#  'champagne blend',
#  'chardonnay',
#  'chasselas',
#  'chenin blanc',
#  'cinsault',
#  'clairette',
#  'concord',
#  'corvina',
#  'counoise',
#  'criolla grande',
#  'croatina',
#  'debina',
#  'dolcetto',
#  'feteasca neagra',
#  'fogoneu',
#  'frankovka',
#  'freisa',
#  'furmint',
#  'galego dourado',
#  'gamaret',
#  'gamay',
#  'garnacha',
#  'garnacha blanca',
#  'garnacha tintorera',
#  'gewurztraminer',
#  'giro',
#  'godello',
#  'graciano',
#  'grasevina',
#  'greco nero',
#  'grenache',
#  'grenache blanc',
#  'grenache tinta',
#  'grenache tintorera',
#  'harslevelu',
#  'juhfark',
#  'kadarka blau',
#  'keknyelu',
#  'kratosija',
#  'lagrein',
#  'liatiko',
#  'limnio',
#  'listan blanco',
#  'listan negro',
#  'lledoner pelut',
#  'macabeo',
#  'malagousia',
#  'malbec',
#  'malvasia',
#  'manto negro',
#  'mantonegro',
#  'marsanne',
#  'marselan',
#  'marzemino',
#  'maturana',
#  'mauzac',
#  'mavro',
#  'mavrodaphne',
#  'melon de bourgogne',
#  'mencia',
#  'merlot',
#  'monastrell',
#  'montepulciano',
#  'morellino',
#  'moristel',
#  'moschofilero',
#  'mourvedre',
#  'mtsvane',
#  'muscadelle',
#  'muscat',
#  'muscat blanc a petits grains',
#  'muscat of alexandria',
#  'nebbiolo',
#  'negoska',
#  'negramoll',
#  'negroamaro',
#  'nerello cappuccio',
#  'nerello mascalese',
#  "nero d'avola",
#  'nielluccio',
#  'norton',
#  'nosiola',
#  'palomino',
#  'pelaverga',
#  'petit sirah',
#  'petit verdot',
#  'pinot blanc',
#  'pinot gris',
#  'pinot meunier',
#  'pinot noir',
#  'pinot noir precoce',
#  'pinotage',
#  'plavac_mali',
#  'poulsard',
#  'prokupac',
#  'raboso',
#  'raboso veronese',
#  'ramisco',
#  'red blend',
#  'rieslaner',
#  'riesling',
#  'rioja red blend',
#  'robola',
#  'roditis',
#  'rome negro',
#  'rondinella',
#  'rose blend',
#  'roussanne',
#  'sagrantino',
#  'sangiovese',
#  'sankt laurent',
#  'saperavi',
#  'sauvignon blanc',
#  'sauvignon gris',
#  'savagnin',
#  'savatiano',
#  'sciaccarello',
#  'semillon',
#  'shiraz and syrah',
#  'sideritis',
#  'silvaner',
#  'syrah',
#  'tanat',
#  'tannat',
#  'tavkveri',
#  'tempranillo',
#  'teran',
#  'tinta barroca',
#  'tinta de toro',
#  'tinta roriz',
#  'tinto cao',
#  'torrontes',
#  'touriga franca',
#  'touriga nacional',
#  'tsolikouri',
#  'verdejo',
#  'verdejo negro',
#  'verdejo tinto',
#  'vidiano',
#  'vijariego negro',
#  'vilana',
#  'vin de liqueur',
#  'viognier',
#  'vranac',
#  'welschriesling',
#  'white blend',
#  'xinomavro',
#  'xynisteri',
#  'zinfandel',
#  'zweigelt']

# %%
# 동일 품종 or 오타 수정
data.loc[data['Grape_Variety'].isin(['albarin negro mencia']), 'Grape_Variety'] = 'albarin negro'
data.loc[data['Grape_Variety'].isin(['aragonez', 'tinta roriz', ]), 'Grape_Variety'] = 'tempranillo'
data.loc[data['Grape_Variety'].isin(['cabernet', 'cabernet savignon']), 'Grape_Variety'] = 'cabernet sauvignon'
data.loc[data['Grape_Variety'].isin(['carinena']), 'Grape_Variety'] = 'carignan'
data.loc[data['Grape_Variety'].isin(['garnacha', 'grenache tinta', ]), 'Grape_Variety'] = 'grenache'
data.loc[data['Grape_Variety'].isin(['garnacha tintorera', 'grenache tintorera']), 'Grape_Variety'] = 'alicante bouschet'
data.loc[data['Grape_Variety'].isin(['pinot noir precoce']), 'Grape_Variety'] = 'pinot noir'
data.loc[data['Grape_Variety'].isin(['shiraz and syrah']), 'Grape_Variety'] = 'syrah'
data.loc[data['Grape_Variety'].isin(['tanat']), 'Grape_Variety'] = 'tannat'

print(data['Grape_Variety'].nunique(), data['Grape_Variety'].unique())
# Out:
# 173 ['malbec' 'cabernet sauvignon' 'pinot noir' 'bastardo' 'merlot' 'syrah'
#  'carmenere' 'zinfandel' 'alicante bouschet' 'palomino' 'cabernet franc'
#  'petit verdot' 'petit sirah' 'gewurztraminer' 'riesling' 'chardonnay'
#  'grenache' 'mauzac' 'mourvedre' 'grenache blanc' 'clairette' 'roussanne'
#  'bourboulenc' 'marsanne' 'saperavi' 'nebbiolo' 'nosiola' 'corvina'
#  'rondinella' 'vranac' 'kratosija' 'galego dourado' 'sauvignon blanc'
#  'pinot gris' 'cinsault' nan 'carignan' 'tempranillo' 'tannat' 'barbera'
#  'marselan' 'pinotage' 'viognier' 'sangiovese' 'tinta barroca'
#  'touriga nacional' 'touriga franca' 'tinto cao' 'bonarda' 'cardin'
#  'freisa' 'raboso veronese' 'greco nero' 'criolla grande' 'torrontes'
#  'aglianico' 'montepulciano' 'graciano' 'muscat' 'counoise' 'norton'
#  'concord' 'chambourcin' 'plavac_mali' 'blatina' 'teran' 'kadarka blau'
#  'gamay' 'blaufrankisch' 'zweigelt' 'sankt laurent' 'grasevina'
#  'xynisteri' 'nielluccio' 'sciaccarello' 'semillon' 'sauvignon gris'
#  'muscadelle' 'poulsard' 'savagnin' 'aligote' 'vin de liqueur'
#  'carignan gris' 'chenin blanc' 'melon de bourgogne' 'brandy' 'mtsvane'
#  'tsolikouri' 'tavkveri' 'croatina' 'morellino' 'brachetto' 'dolcetto'
#  'lagrein' 'sagrantino' "nero d'avola" 'pelaverga' 'albarossa' 'marzemino'
#  'raboso' 'nerello mascalese' 'nerello cappuccio' 'aleatico'
#  'feteasca neagra' 'baga' 'bical' 'ramisco' 'negroamaro' 'pinot meunier'
#  'alfrocheiro preto' 'vijariego negro' 'listan negro' 'red blend'
#  'negramoll' 'listan blanco' 'albillo criolo' 'rioja red blend'
#  'monastrell' 'moristel' 'callet' 'fogoneu' 'manto negro' 'mantonegro'
#  'bobal' 'rome negro' 'giro' 'bordeaux blend red' 'pinot blanc' 'macabeo'
#  'areni noir' 'mencia' 'lledoner pelut' 'garnacha blanca' 'tinta de toro'
#  'maturana' 'albarin negro' 'carrasquin' 'verdejo tinto' 'verdejo'
#  'verdejo negro' 'godello' 'prokupac' 'rose blend' 'gamaret' 'frankovka'
#  'chasselas' 'silvaner' 'rieslaner' 'assyrtiko' 'champagne blend'
#  'white blend' 'mavro' 'robola' 'xinomavro' 'vidiano' 'liatiko' 'vilana'
#  'malagousia' 'malvasia' 'savatiano' 'roditis' 'limnio'
#  'muscat of alexandria' 'muscat blanc a petits grains' 'sideritis'
#  'negoska' 'debina' 'moschofilero' 'mavrodaphne' 'furmint' 'keknyelu'
#  'harslevelu' 'juhfark' 'welschriesling']

# %%
# wine_data_EDA2.ipynb의 17번 cell df['Grape_Variety'].unique() 결과와 비교한 결과

a = ['malbec', 'cabernet sauvignon', 'pinot noir', 'bastardo', 'merlot',
       'syrah', 'carmenere', 'zinfandel', 'alicante bouschet', 'palomino',
       'cabernet franc', 'petit verdot', 'petit sirah', 'gewurztraminer',
       'riesling', 'chardonnay', 'grenache', 'mauzac', 'mourvedre',
       'grenache blanc', 'clairette', 'roussanne', 'bourboulenc',
       'marsanne', 'saperavi', 'nebbiolo', 'nosiola', 'corvina',
       'rondinella', 'vranac', 'kratosija', 'galego dourado',
       'sauvignon blanc', 'pinot gris', 'cinsault', 'carignan',
       'tempranillo', 'tannat', 'barbera', 'marselan', 'pinotage',
       'viognier', 'sangiovese', 'tinta barroca', 'touriga nacional',
       'touriga franca', 'tinto cao', 'bonarda', 'cardin', 'freisa',
       'raboso veronese', 'greco nero', 'criolla grande', 'torrontes',
       'aglianico', 'montepulciano', 'graciano', 'muscat', 'counoise',
       'norton', 'concord', 'chambourcin', 'plavac_mali', 'blatina',
       'teran', 'kadarka blau', 'gamay', 'blaufrankisch', 'zweigelt',
       'sankt laurent', 'grasevina', 'xynisteri', 'nielluccio',
       'sciaccarello', 'semillon', 'sauvignon gris', 'muscadelle',
       'poulsard', 'savagnin', 'aligote', 'vin de liqueur',
       'carignan gris', 'chenin blanc', 'melon de bourgogne', 'brandy',
       'mtsvane', 'tsolikouri', 'tavkveri', 'croatina', 'morellino',
       'brachetto', 'dolcetto', 'lagrein', 'sagrantino', "nero d'avola",
       'pelaverga', 'albarossa', 'marzemino', 'raboso',
       'nerello mascalese', 'nerello cappuccio', 'aleatico',
       'feteasca neagra', 'baga', 'bical', 'ramisco', 'negroamaro',
       'pinot meunier', 'alfrocheiro preto', 'vijariego negro',
       'listan negro', 'red blend', 'negramoll', 'listan blanco',
       'albillo criolo', 'rioja red blend', 'monastrell', 'moristel',
       'callet', 'fogoneu', 'manto negro', 'mantonegro', 'bobal',
       'rome negro', 'giro', 'bordeaux blend red', 'pinot blanc',
       'macabeo', 'areni noir', 'mencia', 'lledoner pelut',
       'garnacha blanca', 'tinta de toro', 'maturana', 'albarin negro',
       'carrasquin', 'verdejo tinto', 'verdejo', 'verdejo negro',
       'godello', 'prokupac', 'rose blend', 'gamaret', 'frankovka',
       'chasselas', 'silvaner', 'rieslaner', 'assyrtiko',
       'champagne blend', 'white blend', 'mavro', 'robola', 'xinomavro',
       'vidiano', 'liatiko', 'vilana', 'malagousia', 'malvasia',
       'savatiano', 'roditis', 'limnio', 'muscat of alexandria',
       'muscat blanc a petits grains', 'sideritis', 'negoska', 'debina',
       'moschofilero', 'mavrodaphne', 'furmint', 'keknyelu', 'harslevelu',
       'juhfark', 'welschriesling']

print(set(data['Grape_Variety'].unique()).symmetric_difference(set(a)))
# Out:
# {nan}

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 138220 entries, 0 to 82931
# Data columns (total 65 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Longitude          138220 non-null  float64
#  1   Latitude           138220 non-null  float64
#  2   Soil Mapping Unit  138220 non-null  int64
#  3   Continent          138220 non-null  object
#  4   Country            138220 non-null  object
#  5   Region Lv1         137600 non-null  object
#  6   Grape_Variety      138020 non-null  object
#  7   SHARE_x            138220 non-null  int64
#  8   WRB4_x             138220 non-null  object
#  9   KOPPEN             138220 non-null  object
#  10  TEXTURE_USDA_x     134160 non-null  float64
#  11  REF_BULK_DENSITY   134160 non-null  float64
#  12  BULK_DENSITY       138220 non-null  float64
#  13  DRAINAGE_x         134160 non-null  object
#  14  ROOT_DEPTH_x       138220 non-null  int64
#  15  AWC_x              138220 non-null  int64
#  16  ROOTS_x            62690 non-null   float64
#  17  IL_x               62690 non-null   float64
#  18  HWSD2_SMU_ID_y     138220 non-null  int64
#  19  SEQUENCE           138220 non-null  int64
#  20  SHARE_y            138220 non-null  int64
#  21  WRB4_y             138220 non-null  object
#  22  ROOT_DEPTH_y       138220 non-null  float64
#  23  ROOTS_y            62690 non-null   float64
#  24  IL_y               62690 non-null   float64
#  25  SWR                51850 non-null   float64
#  26  DRAINAGE_y         134160 non-null  object
#  27  AWC_y              138220 non-null  float64
#  28  COARSE             138220 non-null  int64
#  29  SAND               138220 non-null  int64
#  30  SILT               138220 non-null  int64
#  31  CLAY               138220 non-null  int64
#  32  TEXTURE_USDA_y     134160 non-null  float64
#  33  TEXTURE_SOTER      138220 non-null  object
#  34  BULK               138220 non-null  float64
#  35  REF_BULK           134160 non-null  float64
#  36  ORG_CARBON         138220 non-null  float64
#  37  PH_WATER           138220 non-null  float64
#  38  TOTAL_N            138220 non-null  float64
#  39  CN_RATIO           138220 non-null  int64
#  40  CEC_SOIL           138220 non-null  int64
#  41  CEC_CLAY           138220 non-null  int64
#  42  CEC_EFF            138220 non-null  int64
#  43  TEB                138220 non-null  int64
#  44  BSAT               138220 non-null  int64
#  45  ALUM_SAT           138220 non-null  int64
#  46  ESP                138220 non-null  int64
#  47  TCARBON_EQ         138220 non-null  float64
#  48  GYPSUM             138220 non-null  float64
#  49  ELEC_COND          138220 non-null  int64
#  50  Top12_Grape        138220 non-null  int64
#  51  LatRound           138220 non-null  float64
#  52  LngRound           138220 non-null  float64
#  53  LatInt             138220 non-null  int64
#  54  LngInt             138220 non-null  int64
#  55  lat                138220 non-null  float64
#  56  lon                138220 non-null  float64
#  57  TG                 138220 non-null  float64
#  58  TN                 138220 non-null  float64
#  59  TX                 138220 non-null  float64
#  60  RR                 138220 non-null  float64
#  61  RR1                138220 non-null  float64
#  62  Year               138220 non-null  int64
#  63  lat_int            138220 non-null  int64
#  64  lon_int            138220 non-null  int64
# dtypes: float64(29), int64(26), object(10)
# memory usage: 69.6+ MB

# %%
top12_grape = ['malbec', 'cabernet sauvignon', 'pinot noir', 'merlot', 'grenache',
               'syrah', 'cabernet franc', 'tempranillo', 'nebbiolo', 'sangiovese',
               'montepulciano', 'zinfandel']

data['Top12_Grape'] = 0
data.loc[data['Grape_Variety'].isin(top12_grape), 'Top12_Grape'] = 1
data['Top12_Grape'].value_counts()
# Out:
# Top12_Grape
# 1    92680
# 0    45540
# Name: count, dtype: int64

# %%
# wine_data_EDA2.ipynb의 23번 cell 결과와 비교한 결과

# Top12_Grape
# 1    9268
# 0    4554
# Name: count, dtype: int64

ratio_1 = data['Top12_Grape'].value_counts()[0] / data['Top12_Grape'].value_counts()[1]
ratio_2 = 4554 / 9268

if ratio_1 == ratio_2:
    print('Good')
# Out:
# Good

# %%
grape_dic = {
    'malbec' : 1,
    'cabernet sauvignon' : 2,
    'pinot noir' : 3 ,
    'merlot' : 4,
    'grenache' : 5,
    'syrah' : 6,
    'cabernet franc' :7,
    'tempranillo' : 8,
    'nebbiolo' : 9,
    'sangiovese' : 10,
    'montepulciano' : 11,
    'zinfandel' : 12
}
# "cannot reindex on an axis with duplicate labels" error에서는 reset_index 해줘야 함
data.reset_index(drop = True, inplace = True)
data['Grape_Variety'] = data.loc[data['Top12_Grape'] == 1]['Grape_Variety'].map(grape_dic)
data.loc[data['Grape_Variety'].isnull(), 'Grape_Variety'] = 0
data['Grape_Variety'].value_counts()
# Out:
# Grape_Variety
# 0.0     45540
# 6.0     18990
# 2.0     16510
# 3.0     15050
# 4.0     11110
# 5.0      7760
# 7.0      5530
# 1.0      4400
# 10.0     4370
# 9.0      3880
# 8.0      3300
# 11.0     1080
# 12.0      700
# Name: count, dtype: int64

# %%
# wine_data_EDA2.ipynb의 24번 cell 결과와 비교한 결과

# Grape_Variety
# 0.0     4554
# 6.0     1899
# 2.0     1651
# 3.0     1505
# 4.0     1111
# 5.0      776
# 7.0      553
# 1.0      440
# 10.0     437
# 9.0      388
# 8.0      330
# 11.0     108
# 12.0      70
# Name: count, dtype: int64

data['Grape_Variety'].value_counts() / 10
# Out:
# Grape_Variety
# 0.0     4554.0
# 6.0     1899.0
# 2.0     1651.0
# 3.0     1505.0
# 4.0     1111.0
# 5.0      776.0
# 7.0      553.0
# 1.0      440.0
# 10.0     437.0
# 9.0      388.0
# 8.0      330.0
# 11.0     108.0
# 12.0      70.0
# Name: count, dtype: float64

# %% [markdown]
# ### Wine_data_EDA2
# #### 데이터 결측치 처리

# %%
na_counts = data.isna().sum()
na_counts = na_counts[na_counts > 0]
na_counts
# Out:
# Region Lv1            620
# TEXTURE_USDA_x       4060
# REF_BULK_DENSITY     4060
# DRAINAGE_x           4060
# ROOTS_x             75530
# IL_x                75530
# ROOTS_y             75530
# IL_y                75530
# SWR                 86370
# DRAINAGE_y           4060
# TEXTURE_USDA_y       4060
# REF_BULK             4060
# dtype: int64

# %%
# wine_data_EDA2.ipynb의 32번 cell 결과와 비교한 결과

# Region Lv1            62
# TEXTURE_USDA_x       406
# REF_BULK_DENSITY     406
# DRAINAGE_x           406
# ROOTS_x             7553
# IL_x                7553
# ROOTS_y             7553
# IL_y                7553
# SWR                 8637
# DRAINAGE_y           406
# TEXTURE_USDA_y       406
# REF_BULK             406
# dtype: int64

na_counts / 10
# Out:
# Region Lv1            62.0
# TEXTURE_USDA_x       406.0
# REF_BULK_DENSITY     406.0
# DRAINAGE_x           406.0
# ROOTS_x             7553.0
# IL_x                7553.0
# ROOTS_y             7553.0
# IL_y                7553.0
# SWR                 8637.0
# DRAINAGE_y           406.0
# TEXTURE_USDA_y       406.0
# REF_BULK             406.0
# dtype: float64

# %%
na_counts / len(data) * 100
# Out:
# Region Lv1           0.448560
# TEXTURE_USDA_x       2.937346
# REF_BULK_DENSITY     2.937346
# DRAINAGE_x           2.937346
# ROOTS_x             54.644769
# IL_x                54.644769
# ROOTS_y             54.644769
# IL_y                54.644769
# SWR                 62.487339
# DRAINAGE_y           2.937346
# TEXTURE_USDA_y       2.937346
# REF_BULK             2.937346
# dtype: float64

# %%
# wine_data_EDA2.ipynb의 33번 cell 결과와 비교한 결과

# Region Lv1           0.448560
# TEXTURE_USDA_x       2.937346
# REF_BULK_DENSITY     2.937346
# DRAINAGE_x           2.937346
# ROOTS_x             54.644769
# IL_x                54.644769
# ROOTS_y             54.644769
# IL_y                54.644769
# SWR                 62.487339
# DRAINAGE_y           2.937346
# TEXTURE_USDA_y       2.937346
# REF_BULK             2.937346
# dtype: float64

# %%
drop_cols = ['ROOTS_x', 'IL_x', 'ROOTS_y', 'IL_y', 'SWR']
data.drop(columns = drop_cols, inplace = True)

# %%
# TEXTURE_USDA_x, REF_BULK_DENSITY, DRAINAGE_x, DRAINAGE_y, TEXTURE_USDA_y, REF_BULK 확인
data_na = data[data['TEXTURE_USDA_x'].isna()][['TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'DRAINAGE_x', 'DRAINAGE_y', 'TEXTURE_USDA_y', 'REF_BULK']]
data_na.isna().sum()
# Out:
# TEXTURE_USDA_x      4060
# REF_BULK_DENSITY    4060
# DRAINAGE_x          4060
# DRAINAGE_y          4060
# TEXTURE_USDA_y      4060
# REF_BULK            4060
# dtype: int64

# %%
# wine_data_EDA2.ipynb의 37번 cell 결과와 비교한 결과

# TEXTURE_USDA_x      406
# REF_BULK_DENSITY    406
# DRAINAGE_x          406
# DRAINAGE_y          406
# TEXTURE_USDA_y      406
# REF_BULK            406
# dtype: int64

data_na.isna().sum() / 10
# Out:
# TEXTURE_USDA_x      406.0
# REF_BULK_DENSITY    406.0
# DRAINAGE_x          406.0
# DRAINAGE_y          406.0
# TEXTURE_USDA_y      406.0
# REF_BULK            406.0
# dtype: float64

# %%
data_na_idx = data_na.index.tolist()
data_na_idx[:5]
# Out:
# [68, 69, 70, 71, 72]

# %%
A = data.loc[data_na_idx, 'WRB4_x'].value_counts()
B = len(data[data['WRB4_x'] == 'WR'])
C = len(data[data['WRB4_x'] == 'TC'])

print(A)
print(B)
print(C)
# Out:
# WRB4_x
# TC    3820
# WR     240
# Name: count, dtype: int64
# 240
# 3820

# %%
# wine_data_EDA2.ipynb의 42번 cell 결과와 비교한 결과

# WRB4_x
# TC    382
# WR     24
# Name: count, dtype: int64

print(A / 10)
# Out:
# WRB4_x
# TC    382.0
# WR     24.0
# Name: count, dtype: float64

# %%
data = data.drop(data_na_idx, axis = 0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 134160 entries, 0 to 138219
# Data columns (total 60 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Longitude          134160 non-null  float64
#  1   Latitude           134160 non-null  float64
#  2   Soil Mapping Unit  134160 non-null  int64
#  3   Continent          134160 non-null  object
#  4   Country            134160 non-null  object
#  5   Region Lv1         133540 non-null  object
#  6   Grape_Variety      134160 non-null  float64
#  7   SHARE_x            134160 non-null  int64
#  8   WRB4_x             134160 non-null  object
#  9   KOPPEN             134160 non-null  object
#  10  TEXTURE_USDA_x     134160 non-null  float64
#  11  REF_BULK_DENSITY   134160 non-null  float64
#  12  BULK_DENSITY       134160 non-null  float64
#  13  DRAINAGE_x         134160 non-null  object
#  14  ROOT_DEPTH_x       134160 non-null  int64
#  15  AWC_x              134160 non-null  int64
#  16  HWSD2_SMU_ID_y     134160 non-null  int64
#  17  SEQUENCE           134160 non-null  int64
#  18  SHARE_y            134160 non-null  int64
#  19  WRB4_y             134160 non-null  object
#  20  ROOT_DEPTH_y       134160 non-null  float64
#  21  DRAINAGE_y         134160 non-null  object
#  22  AWC_y              134160 non-null  float64
#  23  COARSE             134160 non-null  int64
#  24  SAND               134160 non-null  int64
#  25  SILT               134160 non-null  int64
#  26  CLAY               134160 non-null  int64
#  27  TEXTURE_USDA_y     134160 non-null  float64
#  28  TEXTURE_SOTER      134160 non-null  object
#  29  BULK               134160 non-null  float64
#  30  REF_BULK           134160 non-null  float64
#  31  ORG_CARBON         134160 non-null  float64
#  32  PH_WATER           134160 non-null  float64
#  33  TOTAL_N            134160 non-null  float64
#  34  CN_RATIO           134160 non-null  int64
#  35  CEC_SOIL           134160 non-null  int64
#  36  CEC_CLAY           134160 non-null  int64
#  37  CEC_EFF            134160 non-null  int64
#  38  TEB                134160 non-null  int64
#  39  BSAT               134160 non-null  int64
#  40  ALUM_SAT           134160 non-null  int64
#  41  ESP                134160 non-null  int64
#  42  TCARBON_EQ         134160 non-null  float64
#  43  GYPSUM             134160 non-null  float64
#  44  ELEC_COND          134160 non-null  int64
#  45  Top12_Grape        134160 non-null  int64
#  46  LatRound           134160 non-null  float64
#  47  LngRound           134160 non-null  float64
#  48  LatInt             134160 non-null  int64
#  49  LngInt             134160 non-null  int64
#  50  lat                134160 non-null  float64
#  51  lon                134160 non-null  float64
#  52  TG                 134160 non-null  float64
#  53  TN                 134160 non-null  float64
#  54  TX                 134160 non-null  float64
#  55  RR                 134160 non-null  float64
#  56  RR1                134160 non-null  float64
#  57  Year               134160 non-null  int64
#  58  lat_int            134160 non-null  int64
#  59  lon_int            134160 non-null  int64
# dtypes: float64(25), int64(26), object(9)
# memory usage: 62.4+ MB

# %%
na_counts = data.isna().sum()
na_counts = na_counts[na_counts > 0]
na_counts
# Out:
# Region Lv1    620
# dtype: int64

# %%
# wine_data_EDA2.ipynb의 49번 cell 결과와 비교한 결과

# Region Lv1    62
# dtype: int64

print(na_counts / 10)
# Out:
# Region Lv1    62.0
# dtype: float64

# %%
data.to_csv('data/wine_total_data_25-70_cleansed.csv', index = False)
data.head()
# Out:
#    Longitude   Latitude  Soil Mapping Unit Continent    Country  \
# 0 -63.358333 -40.766667              12245  Americas  Argentina
# 1 -63.358333 -40.766667              12245  Americas  Argentina
# 2 -63.358333 -40.766667              12245  Americas  Argentina
# 3 -63.358333 -40.766667              12245  Americas  Argentina
# 4 -63.358333 -40.775000              12245  Americas  Argentina
#
#            Region Lv1  Grape_Variety  SHARE_x WRB4_x KOPPEN  TEXTURE_USDA_x  \
# 0  Río Negro Province            1.0       60   FLeu      B            11.0
# 1  Río Negro Province            1.0       60   FLeu      B            11.0
# 2  Río Negro Province            1.0       60   FLeu      B            11.0
# 3  Río Negro Province            1.0       60   FLeu      B            11.0
# 4  Río Negro Province            1.0       60   FLeu      B            11.0
#
#    REF_BULK_DENSITY  BULK_DENSITY DRAINAGE_x  ROOT_DEPTH_x  AWC_x  \
# 0              1.69           1.5         MW             1    142
# 1              1.69           1.5         MW             1    142
# 2              1.69           1.5         MW             1    142
# 3              1.69           1.5         MW             1    142
# 4              1.69           1.5         MW             1    142
#
#    HWSD2_SMU_ID_y  SEQUENCE  SHARE_y WRB4_y  ROOT_DEPTH_y DRAINAGE_y  AWC_y  \
# 0           12245         1       60   FLeu           1.0         MW  142.0
# 1           12245         1       60   FLeu           1.0         MW  142.0
# 2           12245         1       60   FLeu           1.0         MW  142.0
# 3           12245         1       60   FLeu           1.0         MW  142.0
# 4           12245         1       60   FLeu           1.0         MW  142.0
#
#    COARSE  SAND  SILT  CLAY  TEXTURE_USDA_y TEXTURE_SOTER  BULK  REF_BULK  \
# 0       3    55    27    18            11.0             M   1.5      1.69
# 1       3    55    27    18            11.0             M   1.5      1.69
# 2       3    55    27    18            11.0             M   1.5      1.69
# 3       3    55    27    18            11.0             M   1.5      1.69
# 4       3    55    27    18            11.0             M   1.5      1.69
#
#    ORG_CARBON  PH_WATER  TOTAL_N  CN_RATIO  CEC_SOIL  CEC_CLAY  CEC_EFF  TEB  \
# 0        0.78       7.5     0.93         9        14        63       22   22
# 1        0.78       7.5     0.93         9        14        63       22   22
# 2        0.78       7.5     0.93         9        14        63       22   22
# 3        0.78       7.5     0.93         9        14        63       22   22
# 4        0.78       7.5     0.93         9        14        63       22   22
#
#    BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND  Top12_Grape  LatRound  \
# 0    94         0    4         2.0     0.7          2            1     -41.0
# 1    94         0    4         2.0     0.7          2            1     -41.0
# 2    94         0    4         2.0     0.7          2            1     -41.0
# 3    94         0    4         2.0     0.7          2            1     -41.0
# 4    94         0    4         2.0     0.7          2            1     -41.0
#
#    LngRound  LatInt  LngInt    lat    lon          TG         TN         TX  \
# 0     -63.0     -40     -63 -40.75 -63.75  291.832566  281.10263  308.94640
# 1     -63.0     -40     -63 -40.75 -63.25  291.656100  280.79290  308.32434
# 2     -63.0     -40     -63 -40.25 -63.75  292.434964  281.20163  309.82962
# 3     -63.0     -40     -63 -40.25 -63.25  292.091389  280.98373  308.99188
# 4     -63.0     -40     -63 -40.75 -63.75  291.832566  281.10263  308.94640
#
#           RR       RR1  Year  lat_int  lon_int
# 0  12.711205  1.523810  2025      -40      -63
# 1  14.931194  1.571429  2025      -40      -63
# 2  10.477526  1.380952  2025      -40      -63
# 3  14.425991  1.523810  2025      -40      -63
# 4  12.711205  1.523810  2025      -40      -63

# %%
df = pd.read_csv('data/wine_total_data_25-70_cleansed.csv')
df.head()
# Out:
#    Longitude   Latitude  Soil Mapping Unit Continent    Country  \
# 0 -63.358333 -40.766667              12245  Americas  Argentina
# 1 -63.358333 -40.766667              12245  Americas  Argentina
# 2 -63.358333 -40.766667              12245  Americas  Argentina
# 3 -63.358333 -40.766667              12245  Americas  Argentina
# 4 -63.358333 -40.775000              12245  Americas  Argentina
#
#            Region Lv1  Grape_Variety  SHARE_x WRB4_x KOPPEN  TEXTURE_USDA_x  \
# 0  Río Negro Province            1.0       60   FLeu      B            11.0
# 1  Río Negro Province            1.0       60   FLeu      B            11.0
# 2  Río Negro Province            1.0       60   FLeu      B            11.0
# 3  Río Negro Province            1.0       60   FLeu      B            11.0
# 4  Río Negro Province            1.0       60   FLeu      B            11.0
#
#    REF_BULK_DENSITY  BULK_DENSITY DRAINAGE_x  ROOT_DEPTH_x  AWC_x  \
# 0              1.69           1.5         MW             1    142
# 1              1.69           1.5         MW             1    142
# 2              1.69           1.5         MW             1    142
# 3              1.69           1.5         MW             1    142
# 4              1.69           1.5         MW             1    142
#
#    HWSD2_SMU_ID_y  SEQUENCE  SHARE_y WRB4_y  ROOT_DEPTH_y DRAINAGE_y  AWC_y  \
# 0           12245         1       60   FLeu           1.0         MW  142.0
# 1           12245         1       60   FLeu           1.0         MW  142.0
# 2           12245         1       60   FLeu           1.0         MW  142.0
# 3           12245         1       60   FLeu           1.0         MW  142.0
# 4           12245         1       60   FLeu           1.0         MW  142.0
#
#    COARSE  SAND  SILT  CLAY  TEXTURE_USDA_y TEXTURE_SOTER  BULK  REF_BULK  \
# 0       3    55    27    18            11.0             M   1.5      1.69
# 1       3    55    27    18            11.0             M   1.5      1.69
# 2       3    55    27    18            11.0             M   1.5      1.69
# 3       3    55    27    18            11.0             M   1.5      1.69
# 4       3    55    27    18            11.0             M   1.5      1.69
#
#    ORG_CARBON  PH_WATER  TOTAL_N  CN_RATIO  CEC_SOIL  CEC_CLAY  CEC_EFF  TEB  \
# 0        0.78       7.5     0.93         9        14        63       22   22
# 1        0.78       7.5     0.93         9        14        63       22   22
# 2        0.78       7.5     0.93         9        14        63       22   22
# 3        0.78       7.5     0.93         9        14        63       22   22
# 4        0.78       7.5     0.93         9        14        63       22   22
#
#    BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND  Top12_Grape  LatRound  \
# 0    94         0    4         2.0     0.7          2            1     -41.0
# 1    94         0    4         2.0     0.7          2            1     -41.0
# 2    94         0    4         2.0     0.7          2            1     -41.0
# 3    94         0    4         2.0     0.7          2            1     -41.0
# 4    94         0    4         2.0     0.7          2            1     -41.0
#
#    LngRound  LatInt  LngInt    lat    lon          TG         TN         TX  \
# 0     -63.0     -40     -63 -40.75 -63.75  291.832566  281.10263  308.94640
# 1     -63.0     -40     -63 -40.75 -63.25  291.656100  280.79290  308.32434
# 2     -63.0     -40     -63 -40.25 -63.75  292.434964  281.20163  309.82962
# 3     -63.0     -40     -63 -40.25 -63.25  292.091389  280.98373  308.99188
# 4     -63.0     -40     -63 -40.75 -63.75  291.832566  281.10263  308.94640
#
#           RR       RR1  Year  lat_int  lon_int
# 0  12.711205  1.523810  2025      -40      -63
# 1  14.931194  1.571429  2025      -40      -63
# 2  10.477526  1.380952  2025      -40      -63
# 3  14.425991  1.523810  2025      -40      -63
# 4  12.711205  1.523810  2025      -40      -63
