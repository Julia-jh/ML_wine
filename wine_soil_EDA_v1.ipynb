# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./Wine Data/wine_soil_data_0717.csv", index_col = "Column1" , encoding= 'cp1252')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2506 entries, 0 to 2505
# Data columns (total 51 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Longitude          2506 non-null   float64
#  1   Latitude           2506 non-null   float64
#  2   Soil Mapping Unit  2506 non-null   int64
#  3   Continent          2506 non-null   object
#  4   Country            2506 non-null   object
#  5   Region Lv1         2489 non-null   object
#  6   Grape_Variety      2501 non-null   object
#  7   SHARE_x            2506 non-null   int64
#  8   WRB4_x             2506 non-null   object
#  9   KOPPEN             2506 non-null   object
#  10  TEXTURE_USDA_x     2430 non-null   float64
#  11  REF_BULK_DENSITY   2430 non-null   float64
#  12  BULK_DENSITY       2506 non-null   float64
#  13  DRAINAGE_x         2430 non-null   object
#  14  ROOT_DEPTH_x       2506 non-null   int64
#  15  AWC_x              2506 non-null   int64
#  16  ROOTS_x            724 non-null    float64
#  17  IL_x               724 non-null    float64
#  18  HWSD2_SMU_ID_y     2506 non-null   int64
#  19  SEQUENCE           2506 non-null   int64
#  20  SHARE_y            2506 non-null   int64
#  21  WRB4_y             2506 non-null   object
#  22  ROOT_DEPTH_y       2506 non-null   int64
#  23  ROOTS_y            724 non-null    float64
#  24  IL_y               724 non-null    float64
#  25  SWR                514 non-null    float64
#  26  DRAINAGE_y         2430 non-null   object
#  27  AWC_y              2506 non-null   int64
#  28  COARSE             2506 non-null   int64
#  29  SAND               2506 non-null   int64
#  30  SILT               2506 non-null   int64
#  31  CLAY               2506 non-null   int64
#  32  TEXTURE_USDA_y     2430 non-null   float64
#  33  TEXTURE_SOTER      2506 non-null   object
#  34  BULK               2506 non-null   float64
#  35  REF_BULK           2430 non-null   float64
#  36  ORG_CARBON         2506 non-null   float64
#  37  PH_WATER           2506 non-null   float64
#  38  TOTAL_N            2506 non-null   float64
#  39  CN_RATIO           2506 non-null   int64
#  40  CEC_SOIL           2506 non-null   int64
#  41  CEC_CLAY           2506 non-null   int64
#  42  CEC_EFF            2506 non-null   int64
#  43  TEB                2506 non-null   int64
#  44  BSAT               2506 non-null   int64
#  45  ALUM_SAT           2506 non-null   int64
#  46  ESP                2506 non-null   int64
#  47  TCARBON_EQ         2506 non-null   float64
#  48  GYPSUM             2506 non-null   float64
#  49  ELEC_COND          2506 non-null   int64
#  50  Top10_Grape        2506 non-null   int64
# dtypes: float64(18), int64(23), object(10)
# memory usage: 1018.1+ KB

# %%
df['Region Lv1'].unique()
# Out:
# array(['R’o Negro Province', 'NeuquŽn Province', 'Southern Chile',
#        'Central Valley', 'Robertson', 'California', 'Colorado',
#        'Littoral Croatia', 'Alsace', 'Bordeaux', 'Burgundy',
#        'Champagne Ð Champagne', 'Languedoc-Roussillon', 'Rh™ne',
#        'Alazani Valley', 'Piedmont', 'Trentino-Alto Adige', 'Veneto',
#        'Tikves', 'Carcavelos', 'Lower Murray', 'Mount Lofty Ranges',
#        "Hawke's Bay", 'Port Phillip', 'Buenos Aires Province',
#        'Aconcagua', 'Coquimbo', 'Mendoza Province', 'Maldonado',
#        'Montevideo', 'Canelones', 'San JosŽ', 'Colonia', 'Elim', 'Elgin',
#        'Stellenbosch', 'Swartland', 'Franschhoek', 'Paarl', 'Tulbagh',
#        'Constantia', 'Durbanville', 'Breede River Valley', 'Little Karoo',
#        'San Juan Province', 'Salta Province', 'La Rioja Province',
#        'Orange River Valley', 'Rio Grande do Sul', 'Paran‡',
#        'Santa Catarina', 'Tarija Department', 'Ica Region', 'QuerŽtaro',
#        'Coahuila / Durango', 'Zacatecas', 'central northern Mexico',
#        'Texas', 'Arizona', 'Baja California', 'New Mexico', 'Virginia',
#        'Missouri', 'Oregon', 'New Jersey', 'New York',
#        'Thracian Lowlands', nan, 'Valley of the Struma River', 'Ontario',
#        'Danubian Plain', 'Michigan', 'Washington', 'Burgenland', 'Wagram',
#        'Vienna', 'British Columbia', 'Commandaria', 'Limassol', 'Moravia',
#        'Bohemia', 'Loire Valley', 'Corsica', 'Savoie', 'Jura', 'Kakheti',
#        'Racha-Lechkhumi', 'Kartli', 'Imereti', 'Ahr', 'Ningxia',
#        'Qiu Shan Valley', 'Yunnan', 'Galilee', 'Judean Hills',
#        'Bekaa Valley', 'Lombardy', 'Marche', 'Tuscany', 'Umbria',
#        'Sicily', 'Sardinia', 'Alentejo', 'Bairrada', 'Colares', 'Barossa',
#        'Limestone Coast', 'Far North', 'Fleurieu', 'Big Rivers',
#        'Canberra District wine region', 'Central Ranges',
#        'Central Victoria', 'Gippsland', 'North East Victoria',
#        'Southern New South Wales', 'Hunter Valley', 'Pipers River',
#        'South Coast', 'Western Victoria', 'Central Otago',
#        'North West Victoria', 'Coal River', 'Tamar Valley',
#        'Derwent Valley', 'Granite Belt', 'Northern Tablelands',
#        'Great Southern', 'South Western Australia', 'Perth Hills',
#        'Swan Valley', 'Auckland', 'Canterbury', 'Gisborne', 'Marlborough',
#        'Nelson', 'Wairarapa', 'Waitaki Valley'], dtype=object)

# %%
# Region 에 (GI) 붙어있는 경우 해당 문자열 삭제

import re

def clean_text(text):
    if pd.isna(text):
        return text
    return re.sub(r'\s*\([^)]*\)', '', text).strip()

df['Region Lv1'] = df['Region Lv1'].apply(clean_text)

# %%
# 결측치 있는 Column만 확인
na_counts = df.isna().sum()
col_na = na_counts[na_counts != 0]
col_na
# Out:
# Region Lv1            17
# Grape_Variety          5
# TEXTURE_USDA_x        76
# REF_BULK_DENSITY      76
# DRAINAGE_x            76
# ROOTS_x             1782
# IL_x                1782
# ROOTS_y             1782
# IL_y                1782
# SWR                 1992
# DRAINAGE_y            76
# TEXTURE_USDA_y        76
# REF_BULK              76
# dtype: int64

# %%
# 결측치가 있는 Column의 전체 데이터 대비 결측치 비율
col_na/len(df)*100
# Out:
# Region Lv1           0.678372
# Grape_Variety        0.199521
# TEXTURE_USDA_x       3.032721
# REF_BULK_DENSITY     3.032721
# DRAINAGE_x           3.032721
# ROOTS_x             71.109338
# IL_x                71.109338
# ROOTS_y             71.109338
# IL_y                71.109338
# SWR                 79.489226
# DRAINAGE_y           3.032721
# TEXTURE_USDA_y       3.032721
# REF_BULK             3.032721
# dtype: float64

# %% [markdown]
# 결측치가 70% 이상 존재하는 Column
# - AWC(식물 성장을 위한 토양 최대 수분 보유량), DRAINAGE(토양 배수 능력) Column이 있어서 제외하고 가도 될듯 함
#
# - ROOTS_x : 최상위 토양 뿌리 장애물 깊이
# - IL_x : 토양 프로파일 내에 있는 불투수층
# - ROOTS_y : 1번째 레이어 토양 뿌리 장애물 깊이
# - IL_y : 토양 프로파일 내에 있는 불투수층
# - SWR : 토양 수분 체제

# %%
# Drop할 Column 
col_drop = ['ROOTS_x', 'IL_x', 'ROOTS_y', 'IL_y', 'SWR']
df.drop(col_drop, axis =1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2506 entries, 0 to 2505
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Longitude          2506 non-null   float64
#  1   Latitude           2506 non-null   float64
#  2   Soil Mapping Unit  2506 non-null   int64
#  3   Continent          2506 non-null   object
#  4   Country            2506 non-null   object
#  5   Region Lv1         2489 non-null   object
#  6   Grape_Variety      2501 non-null   object
#  7   SHARE_x            2506 non-null   int64
#  8   WRB4_x             2506 non-null   object
#  9   KOPPEN             2506 non-null   object
#  10  TEXTURE_USDA_x     2430 non-null   float64
#  11  REF_BULK_DENSITY   2430 non-null   float64
#  12  BULK_DENSITY       2506 non-null   float64
#  13  DRAINAGE_x         2430 non-null   object
#  14  ROOT_DEPTH_x       2506 non-null   int64
#  15  AWC_x              2506 non-null   int64
#  16  HWSD2_SMU_ID_y     2506 non-null   int64
#  17  SEQUENCE           2506 non-null   int64
#  18  SHARE_y            2506 non-null   int64
#  19  WRB4_y             2506 non-null   object
#  20  ROOT_DEPTH_y       2506 non-null   int64
#  21  DRAINAGE_y         2430 non-null   object
#  22  AWC_y              2506 non-null   int64
#  23  COARSE             2506 non-null   int64
#  24  SAND               2506 non-null   int64
#  25  SILT               2506 non-null   int64
#  26  CLAY               2506 non-null   int64
#  27  TEXTURE_USDA_y     2430 non-null   float64
#  28  TEXTURE_SOTER      2506 non-null   object
#  29  BULK               2506 non-null   float64
#  30  REF_BULK           2430 non-null   float64
#  31  ORG_CARBON         2506 non-null   float64
#  32  PH_WATER           2506 non-null   float64
#  33  TOTAL_N            2506 non-null   float64
#  34  CN_RATIO           2506 non-null   int64
#  35  CEC_SOIL           2506 non-null   int64
#  36  CEC_CLAY           2506 non-null   int64
#  37  CEC_EFF            2506 non-null   int64
#  38  TEB                2506 non-null   int64
#  39  BSAT               2506 non-null   int64
#  40  ALUM_SAT           2506 non-null   int64
#  41  ESP                2506 non-null   int64
#  42  TCARBON_EQ         2506 non-null   float64
#  43  GYPSUM             2506 non-null   float64
#  44  ELEC_COND          2506 non-null   int64
#  45  Top10_Grape        2506 non-null   int64
# dtypes: float64(13), int64(23), object(10)
# memory usage: 920.2+ KB

# %%
# 76개의 같은 인덱스가 아래 6개 Column에 대해 결측치를 가지고 있는 것으로 확인
df[df['TEXTURE_USDA_x'].isna()][['TEXTURE_USDA_x', 'REF_BULK_DENSITY', 'DRAINAGE_x', 'DRAINAGE_y', 'TEXTURE_USDA_y', 'REF_BULK']].isna().sum()
# Out:
# TEXTURE_USDA_x      76
# REF_BULK_DENSITY    76
# DRAINAGE_x          76
# DRAINAGE_y          76
# TEXTURE_USDA_y      76
# REF_BULK            76
# dtype: int64

# %%
# 결측치 76개중 75개는 TC로 농업이 불가능한 토양으로 삭제 / 전체 TC 데이터가 모두 여기에 포함되어 있음
# WR 또한 전체 데이터 중 1개로 해당 row 삭제
df[df['TEXTURE_USDA_x'].isna()]['WRB4_x'].value_counts()
# Out:
# WRB4_x
# TC    75
# WR     1
# Name: count, dtype: int64

# %%
df['WRB4_x'].value_counts()
# Out:
# WRB4_x
# CMeu         309
# PLeu         268
# LVcr         214
# LVha         121
# CMca         110
# LPli          93
# CMdy          92
# CLpt          87
# TC            75
# ACha          65
# LXfr          64
# PHlv          60
# PHha          59
# LVcc          55
# LVgl          53
# RGeu          50
# UMcm          49
# LPeu          48
# RGca          47
# CLha          43
# LPrz          38
# PZal          36
# CMcr          34
# VR            34
# KSha          34
# PZcb          33
# ACgl          33
# SNha          23
# GLeu          22
# CMvr          22
# FLca          22
# FLeu          21
# AR            20
# VRha          18
# CHha          18
# NT            17
# Nthu          14
# UMac          12
# ALha          11
# RGdy          11
# FRro          10
# CHcc           7
# HS             6
# FLdy           6
# PLdy           5
# STrt           4
# PHcc           4
# LVab           4
# ANvi           4
# PHgl           3
# LVvr           3
# SCha           3
# LPmo           3
# ATpa&ATtr      2
# RTeu           2
# ARcq           1
# KSlv           1
# GLum           1
# WR             1
# AN             1
# Name: count, dtype: int64

# %%
drop_row = df[df['TEXTURE_USDA_x'].isna()].index.to_list()
len(drop_row)
# Out:
# 76

# %%
df.drop(drop_row, axis = 0, inplace = True)
df.isna().sum()
# Out:
# Longitude             0
# Latitude              0
# Soil Mapping Unit     0
# Continent             0
# Country               0
# Region Lv1           17
# Grape_Variety         5
# SHARE_x               0
# WRB4_x                0
# KOPPEN                0
# TEXTURE_USDA_x        0
# REF_BULK_DENSITY      0
# BULK_DENSITY          0
# DRAINAGE_x            0
# ROOT_DEPTH_x          0
# AWC_x                 0
# HWSD2_SMU_ID_y        0
# SEQUENCE              0
# SHARE_y               0
# WRB4_y                0
# ROOT_DEPTH_y          0
# DRAINAGE_y            0
# AWC_y                 0
# COARSE                0
# SAND                  0
# SILT                  0
# CLAY                  0
# TEXTURE_USDA_y        0
# TEXTURE_SOTER         0
# BULK                  0
# REF_BULK              0
# ORG_CARBON            0
# PH_WATER              0
# TOTAL_N               0
# CN_RATIO              0
# CEC_SOIL              0
# CEC_CLAY              0
# CEC_EFF               0
# TEB                   0
# BSAT                  0
# ALUM_SAT              0
# ESP                   0
# TCARBON_EQ            0
# GYPSUM                0
# ELEC_COND             0
# Top10_Grape           0
# dtype: int64

# %%
na_counts = df.isna().sum()
col_na = na_counts[na_counts != 0]
col_na
# Out:
# Region Lv1       17
# Grape_Variety     5
# dtype: int64

# %%
# Region Lv1의 누락 값은 머신러닝에 영향을 주지 않는 요소로 그대로 둠
[df['Region Lv1'].isna()]
# Out:
#          Longitude   Latitude  Soil Mapping Unit Continent  \
# Column1
# 920      18.325000  42.708333              10530    Europe
# 921      18.333333  42.708333              10530    Europe
# 925      17.541667  43.208333              10530    Europe
# 926      17.691667  43.225000              10530    Europe
# 927      17.691667  43.225000              10530    Europe
# 928      17.691667  43.225000              10530    Europe
# 935      17.691667  43.216667              10523    Europe
# 936      17.691667  43.216667              10523    Europe
# 937      17.691667  43.216667              10523    Europe
# 1333     35.858333  35.500000               3496      Asia
# 1334     35.858333  35.500000               3496      Asia
# 1335     35.858333  35.500000               3496      Asia
# 1816     28.858333  47.133333               7542    Europe
# 1817     28.858333  47.133333               7542    Europe
# 1818     28.850000  47.133333               7542    Europe
# 1819     29.875000  46.550000               7545    Europe
# 1820     29.883333  46.550000               7545    Europe
#
#                         Country Region Lv1       Grape_Variety  SHARE_x  \
# Column1
# 920      Bosnia and Herzegovina        NaN              vranac       60
# 921      Bosnia and Herzegovina        NaN              vranac       60
# 925      Bosnia and Herzegovina        NaN             blatina       60
# 926      Bosnia and Herzegovina        NaN             blatina       60
# 927      Bosnia and Herzegovina        NaN              vranac       60
# 928      Bosnia and Herzegovina        NaN         plavac_mali       60
# 935      Bosnia and Herzegovina        NaN             blatina       75
# 936      Bosnia and Herzegovina        NaN              vranac       75
# 937      Bosnia and Herzegovina        NaN         plavac_mali       75
# 1333                      Syria        NaN  cabernet sauvignon       30
# 1334                      Syria        NaN              merlot       30
# 1335                      Syria        NaN               syrah       30
# 1816                    Moldova        NaN     feteasca neagra       90
# 1817                    Moldova        NaN            saperavi       90
# 1818                    Moldova        NaN          pinot noir       90
# 1819                    Moldova        NaN  cabernet sauvignon      100
# 1820                    Moldova        NaN  cabernet sauvignon      100
#
#         WRB4_x KOPPEN  ...  CEC_CLAY  CEC_EFF  TEB BSAT  ALUM_SAT  ESP  \
# Column1                ...
# 920       LPli      C  ...        35       20   10   64         0    3
# 921       LPli      C  ...        35       20   10   64         0    3
# 925       LPli      C  ...        35       20   10   64         0    3
# 926       LPli      C  ...        35       20   10   64         0    3
# 927       LPli      C  ...        35       20   10   64         0    3
# 928       LPli      C  ...        35       20   10   64         0    3
# 935       FLca      D  ...        55       30   30   99         0    4
# 936       FLca      D  ...        55       30   30   99         0    4
# 937       FLca      D  ...        55       30   30   99         0    4
# 1333      CMeu      C  ...        54       15   14   82         0    2
# 1334      CMeu      C  ...        54       15   14   82         0    2
# 1335      CMeu      C  ...        54       15   14   82         0    2
# 1816      CHcc      D  ...        63       34   34   98         0    1
# 1817      CHcc      D  ...        63       34   34   98         0    1
# 1818      CHcc      D  ...        63       34   34   98         0    1
# 1819      CHcc      D  ...        63       34   34   98         0    1
# 1820      CHcc      D  ...        63       34   34   98         0    1
#
#          TCARBON_EQ  GYPSUM  ELEC_COND Top10_Grape
# Column1
# 920             0.0     0.3          1           0
# 921             0.0     0.3          1           0
# 925             0.0     0.3          1           0
# 926             0.0     0.3          1           0
# 927             0.0     0.3          1           0
# 928             0.0     0.3          1           0
# 935            22.6     0.5          2           0
# 936            22.6     0.5          2           0
# 937            22.6     0.5          2           0
# 1333            0.0     1.6          2           1
# 1334            0.0     1.6          2           1
# 1335            0.0     1.6          2           1
# 1816            6.9     0.8          1           0
# 1817            6.9     0.8          1           0
# 1818            6.9     0.8          1           1
# 1819            6.9     0.8          1           1
# 1820            6.9     0.8          1           1
#
# [17 rows x 46 columns]

# %%
# 이전 데이터 확인해보니 데이터 클렌징하면서 잘못된 값 삭제하며 Null값으로 변환함
# Top10 Grape 에서 1 or 0으로 나뉘니 여기도 두고 가도 좋을 듯 함.. 포도를 재배하는 토양 특성을 살리기 위해?
df[df['Grape_Variety'].isna()]
# Out:
#           Longitude   Latitude  Soil Mapping Unit Continent Country  \
# Column1
# 97       -72.550000 -36.583333              13468  Americas   Chile
# 98       -72.675000 -36.583333              13468  Americas   Chile
# 99       -72.666667 -36.583333              13468  Americas   Chile
# 706     -116.591667  32.500000              18265  Americas  Mexico
# 1255       4.850000  44.108333               9400    Europe  France
#
#               Region Lv1 Grape_Variety  SHARE_x WRB4_x KOPPEN  ...  CEC_CLAY  \
# Column1                                                        ...
# 97        Southern Chile           NaN       50   ALha      C  ...        26
# 98        Southern Chile           NaN       50   ALha      C  ...        26
# 99        Southern Chile           NaN       50   ALha      C  ...        26
# 706      Baja California           NaN       43   LPli      B  ...        35
# 1255               Rh™ne           NaN       90   FLca      C  ...        52
#
#          CEC_EFF  TEB BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND  \
# Column1
# 97             6    5   47        21    1         0.0     0.1          0
# 98             6    5   47        21    1         0.0     0.1          0
# 99             6    5   47        21    1         0.0     0.1          0
# 706           25   10   64         0    3         6.3     0.3          1
# 1255          29   28  100         0    2        10.1     0.5          2
#
#         Top10_Grape
# Column1
# 97                0
# 98                0
# 99                0
# 706               0
# 1255              0
#
# [5 rows x 46 columns]

# %%
# 중간 저장하기
df.to_csv("./Wine Data/wine_soil_EDA_v1.csv", index = True)

# %% [markdown]
# ### 데이터 시각화

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2430 entries, 0 to 2505
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Longitude          2430 non-null   float64
#  1   Latitude           2430 non-null   float64
#  2   Soil Mapping Unit  2430 non-null   int64
#  3   Continent          2430 non-null   object
#  4   Country            2430 non-null   object
#  5   Region Lv1         2413 non-null   object
#  6   Grape_Variety      2425 non-null   object
#  7   SHARE_x            2430 non-null   int64
#  8   WRB4_x             2430 non-null   object
#  9   KOPPEN             2430 non-null   object
#  10  TEXTURE_USDA_x     2430 non-null   float64
#  11  REF_BULK_DENSITY   2430 non-null   float64
#  12  BULK_DENSITY       2430 non-null   float64
#  13  DRAINAGE_x         2430 non-null   object
#  14  ROOT_DEPTH_x       2430 non-null   int64
#  15  AWC_x              2430 non-null   int64
#  16  HWSD2_SMU_ID_y     2430 non-null   int64
#  17  SEQUENCE           2430 non-null   int64
#  18  SHARE_y            2430 non-null   int64
#  19  WRB4_y             2430 non-null   object
#  20  ROOT_DEPTH_y       2430 non-null   int64
#  21  DRAINAGE_y         2430 non-null   object
#  22  AWC_y              2430 non-null   int64
#  23  COARSE             2430 non-null   int64
#  24  SAND               2430 non-null   int64
#  25  SILT               2430 non-null   int64
#  26  CLAY               2430 non-null   int64
#  27  TEXTURE_USDA_y     2430 non-null   float64
#  28  TEXTURE_SOTER      2430 non-null   object
#  29  BULK               2430 non-null   float64
#  30  REF_BULK           2430 non-null   float64
#  31  ORG_CARBON         2430 non-null   float64
#  32  PH_WATER           2430 non-null   float64
#  33  TOTAL_N            2430 non-null   float64
#  34  CN_RATIO           2430 non-null   int64
#  35  CEC_SOIL           2430 non-null   int64
#  36  CEC_CLAY           2430 non-null   int64
#  37  CEC_EFF            2430 non-null   int64
#  38  TEB                2430 non-null   int64
#  39  BSAT               2430 non-null   int64
#  40  ALUM_SAT           2430 non-null   int64
#  41  ESP                2430 non-null   int64
#  42  TCARBON_EQ         2430 non-null   float64
#  43  GYPSUM             2430 non-null   float64
#  44  ELEC_COND          2430 non-null   int64
#  45  Top10_Grape        2430 non-null   int64
# dtypes: float64(13), int64(23), object(10)
# memory usage: 892.3+ KB

# %%
# 토양 관련 Column만 통계 수치 살펴보기
df[df.columns[7:]].describe()
# Out:
#            SHARE_x  TEXTURE_USDA_x  REF_BULK_DENSITY  BULK_DENSITY  \
# count  2430.000000     2430.000000       2430.000000   2430.000000
# mean     56.274897        8.310700          1.724984      1.381424
# std      17.169012        2.265464          0.145701      0.136292
# min      20.000000        3.000000          0.970000      0.540000
# 25%      45.000000        7.000000          1.700000      1.300000
# 50%      50.000000        9.000000          1.720000      1.410000
# 75%      70.000000        9.000000          1.810000      1.450000
# max     100.000000       12.000000          2.030000      1.720000
#
#        ROOT_DEPTH_x        AWC_x  HWSD2_SMU_ID_y  SEQUENCE      SHARE_y  \
# count   2430.000000  2430.000000     2430.000000    2430.0  2430.000000
# mean       1.443210   130.379424    10815.129630       1.0    56.274897
# std        0.892691    54.090512     7297.584455       0.0    17.169012
# min        1.000000    10.000000     3334.000000       1.0    20.000000
# 25%        1.000000   110.000000     6006.000000       1.0    45.000000
# 50%        1.000000   150.000000     9658.000000       1.0    50.000000
# 75%        1.000000   170.000000    12242.000000       1.0    70.000000
# max        4.000000   214.000000    30414.000000       1.0   100.000000
#
#        ROOT_DEPTH_y  ...     CEC_CLAY      CEC_EFF          TEB         BSAT  \
# count   2430.000000  ...  2430.000000  2430.000000  2430.000000  2430.000000
# mean       1.443210  ...    47.946914    17.228395    16.152263    76.261728
# std        0.892691  ...    15.269962    10.355164    10.577590    19.520556
# min        1.000000  ...     9.000000     3.000000     2.000000    10.000000
# 25%        1.000000  ...    38.000000     9.000000     8.000000    71.000000
# 50%        1.000000  ...    47.000000    15.000000    14.000000    80.000000
# 75%        1.000000  ...    57.000000    21.000000    20.000000    93.000000
# max        4.000000  ...   110.000000    52.000000    50.000000   100.000000
#
#           ALUM_SAT          ESP   TCARBON_EQ       GYPSUM    ELEC_COND  \
# count  2430.000000  2430.000000  2430.000000  2430.000000  2430.000000
# mean      4.522634     2.252675     3.109506     0.682016     0.897119
# std       9.370870     2.279995     6.749505     0.925523     0.826755
# min       0.000000     1.000000     0.000000     0.000000     0.000000
# 25%       0.000000     1.000000     0.000000     0.000000     0.000000
# 50%       0.000000     2.000000     0.000000     0.100000     1.000000
# 75%       0.000000     3.000000     1.600000     1.600000     1.000000
# max      40.000000    38.000000    27.300000     4.000000    16.000000
#
#        Top10_Grape
# count  2430.000000
# mean      0.750617
# std       0.432745
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 33 columns]
