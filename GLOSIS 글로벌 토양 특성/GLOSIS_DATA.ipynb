# %% [markdown]
# ***데이터 출처***
#
# - https://www.fao.org/soils-portal/data-hub/soil-maps-and-databases/harmonized-world-soil-database-v20/en/

# %% [markdown]
# - 어떻게 merge 시킨 데이터를 사용할 것인지?
#     1. merge_data : 한 지점의 7개의 층 별로 데이터가 있는 테이블
#     2. merge_data_2 : 한 지점의 1개의 층 데이터만 있는 테이블
# - 컬럼은 어떤것?
# - 나라 이름은 어떻게 확인?

# %% [markdown]
# ### 컬럼 정보
#
# - ID : 데이터 베이스 id
# - HWSD2_SMU_ID ,HWSD1_SMU_ID ,WISE30s_SMU_ID: Soil Mapping Unit 번호
# - COVERAGE : Data source: ESDB, SOTWIS, DSMW, China, Afghanistan, Ghana, Türkiye.
# - SHARE(Share of the soil unit) : share of the soil unit within the mapping unit in percentage.
# -  WRB4 : the name of the Soil Reference Group plus the most important
# primary qualifier(4글자)
# - WRB_PHASES :  the full symbol of the WRB soil name taking
# into account phases and referring to the Soil Reference Group plus all primary qualifier
# - WRB2 : the name of the Soil Reference Group plus the most important
# primary qualifier(2글자)
# - WRB2_CODE : the name of the Soil Reference Group plus the most important
# primary qualifier(코드번호)
# - FAO90 :  the name of the soil unit in the FAO90 Revised Legend
# - KOPPEN :  Kӧppen-Geiger climate classes (Tropical, Arid, Temperate,
# Cold and Polar)
# - TEXTURE_USDA : Texture class (USDA conventions)
# - REF_BULK_DENSITY : Reference bulk density is a property of particulate
# materials. It is the mass of many particles of the material divided by the volume they occupy.
# The volume includes the space between particles as well as the space inside the pores of
# individual particles
# - BULK_DENSITY : Bulk density is defined as “the mass of the many particles of the
# material divided by the total volume they occupy”
# - DRAINAGE : soil drainage refers to the natural capability of a soil to
# remove excess water.
#
# - ROOT_DEPTH : the depth to which plants can exploit the soil for nutrients and
# moisture.
#
# - AWC :  the maximum amount of water that the soil can hold that is
# available for plant growth
#
# - PHASE1 ,PHASE2 : phases are subdivisions of soil units based on characteristics which
# are significant for the use or management of the land but are not diagnostic for the
# separation of the soil units themselves
#
# - ROOTS : Obstacle to roots: provides the depth class of an obstacle to roots.(ESDB)
# - IL : Impermeable layer: indicates the presence of an impermeable layer within the soil
# profile. (ESDB)
#
# - ADD_PROP (Additional property) :  certain soil properties, inherent to the soil unit definition
# that are relevant for agricultural use of the soil are vertic and gelic. The additional field provides
# details on gelic properties (gelic soil groups in FAO90) and vertic properties (Vertisols, vertic
# soil groups in FAO90).
#
# - SWR : Soil Water Regime (ESDB)
#
# - LAYER : Depth Layer (from D1 to D7)
#
# - TOPDEP : Depth of top of layer
#
# - BOTDEP : Depth of bottom of layer
#
# - COARSE : Coarse fragments
# - SAND
# - SILT
# - CLAY
# - TEXTURE_SOTER : Texture class (SOTER conventions)
# - BULK : Bulk Density
# - REF_BULK : Reference Bulk Density
# - ORG_CARBON : Organic Carbon Content
# - PH_WATER :pH in water
# - TOTAL_N :Total nitrogen content
# - CN_RATIO :Carbon/Nitrogen ratio (C/N)
# - CEC_SOIL : CEC soil, CATION EXCHANGE CAPACITY (CEC) of the fine earth fraction (cmolc/kg). The total nutrient
# fixing capacity of a soil is well expressed by its Cation Exchange Capacity.
# - CEC_CLAY :CEC clay,corrected for contribution of organic matter (cmolc/kg).
# - CEC_EFF :. ECEC is defined as the sum of exchangeable (Ca++, Mg++,
# K+, Na+) plus the sum of exchangeable (H+, Al+++) (Van Reeuwijk, 2002).
# - TEB :Total exchangeable bases stand for the sum of
# exchangeable cations in a soil: sodium (Na+), calcium (Ca++), magnesium (Mg++) and Potassium
# (K+).
# - BSAT : The base saturation measures the sum
# of exchangeable cations (nutrients) Na+, Ca++, Mg++ and K+ as a percentage of the overall
# exchange capacity of the soil (including the same cations plus H+ and Al+++)
# - ALUM_SAT : The exchangeable aluminum
# percentage (ALSA) has been set at zero when pHwater is higher than 5.5
# -  ESP : The exchangeable sodium percentage has been used to indicate levels of sodium in soils.
# - TCARBON_EQ : Calcium Carbonate
# - GYPSUM : Gypsum is a chemical compound (a salt) which
# occurs occasionally in soils particularly in the driest areas of the globe where it can occur in a
# flower-like form typically opaque with embedded sand grains called desert rose.
# - ELEC_COND :  Coastal and desert soils can be enriched with water-soluble
# salts or salts more soluble than gypsum. The salt content of a soil can be roughly estimated from
# the Electrical Conductivity of the soil measured in a saturated soil paste or a more diluted
# suspension of soil in water

# %% [markdown]
# 포도 품종 예측에 필요한 컬럼
#
# 1. COVERAGE: Data source가 포함되어 있으므로 중요한 메타데이터 정보.
# 2. SHARE: Mapping unit 내에서의 토양 유닛의 비율.
# 3. WRB4: 주요 토양 참조 그룹과 주요 1차 지시자를 나타냄.
# 4. WRB_PHASES: WRB 토양 이름의 전체 기호.
# 5. WRB2: 주요 토양 참조 그룹과 주요 1차 지시자를 나타냄.
# 6. FAO90: FAO90 수정 전설의 토양 단위 이름.
# 7. KOPPEN: Kӧppen-Geiger 기후 클래스.
# 8. TEXTURE_USDA: USDA 규약에 따른 토양 질감 클래스.
# 9. REF_BULK_DENSITY: 참고 상대 밀도.
# 10. BULK_DENSITY: 상대 밀도.
# 11. DRAINAGE: 토양 배수 능력.
# 12. ROOT_DEPTH: 식물이 토양에서 영양분과 수분을 이용할 수 있는 깊이.
# 13. AWC: 식물 성장을 위한 토양의 최대 수분 보유량.
# 14. PHASE1, PHASE2: 토양 단위의 특성.
# 15. ROOTS: 뿌리의 장애물.
# 16. IL: 토양 프로파일 내에 있는 불투수층.
# 17. ADD_PROP: 농업적 이용에 관련된 특정 토양 특성.
# 18. SWR: 토양 수분 체제.
# 19. COARSE: 굵은 입자 비율.
# 20. SAND: 모래 비율.
# 21. SILT: 미사 비율.
# 22. CLAY: 점토 비율.
# 23. TEXTURE_SOTER: SOTER 규약에 따른 토양 질감 클래스.
# 24. BULK: 상대 밀도.
# 25. ORG_CARBON: 유기 탄소 함량.
# 26. PH_WATER: 물에서의 pH.
# 27. TOTAL_N: 총 질소 함량.
# 28. CN_RATIO: 탄소/질소 비율.
# 30. CEC_SOIL: 토양의 양이온 교환 능력.
# 31. CEC_CLAY: 점토의 양이온 교환 능력.
# 32. CEC_EFF: 유효 양이온 교환 능력.
# 33. TEB: 총 교환 가능한 염기.
# 34. BSAT: 염기 포화도.
# 35. ALUM_SAT: 교환 가능한 알루미늄 비율.
# 36. ESP: 교환 가능한 나트륨 비율.
# 37. TCARBON_EQ: 칼슘 탄산염 함량.
# 38. GYPSUM: 석고 함량.
# 39. ELEC_COND: 전기 전도도 (염분 함량 평가에 사용됨).

# %%
merge_data.columns
# Out:
# Index(['ID_x', 'HWSD2_SMU_ID', 'WISE30s_SMU_ID_x', 'HWSD1_SMU_ID_x',
#        'COVERAGE_x', 'SHARE_x', 'WRB4_x', 'WRB_PHASES_x', 'WRB2_x',
#        'WRB2_CODE', 'FAO90_x', 'KOPPEN', 'TEXTURE_USDA_x', 'REF_BULK_DENSITY',
#        'BULK_DENSITY', 'DRAINAGE_x', 'ROOT_DEPTH_x', 'AWC_x', 'PHASE1_x',
#        'PHASE2_x', 'ROOTS_x', 'IL_x', 'ADD_PROP_x', 'ID_y', 'NSC_MU_SOURCE1',
#        'NSC_MU_SOURCE2', 'WISE30s_SMU_ID_y', 'HWSD1_SMU_ID_y', 'COVERAGE_y',
#        'SEQUENCE', 'SHARE_y', 'NSC', 'WRB_PHASES_y', 'WRB4_y', 'WRB2_y',
#        'FAO90_y', 'ROOT_DEPTH_y', 'PHASE1_y', 'PHASE2_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'ADD_PROP_y', 'LAYER', 'TOPDEP', 'BOTDEP',
#        'COARSE', 'SAND', 'SILT', 'CLAY', 'TEXTURE_USDA_y', 'TEXTURE_SOTER',
#        'BULK', 'REF_BULK', 'ORG_CARBON', 'PH_WATER', 'TOTAL_N', 'CN_RATIO',
#        'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF', 'TEB', 'BSAT', 'ALUM_SAT', 'ESP',
#        'TCARBON_EQ', 'GYPSUM', 'ELEC_COND'],
#       dtype='object')

# %%
len(HWSD2_LAYERS['HWSD2_SMU_ID'].unique())
# Out:
# 7530

# %%
import pandas as pd

HWSD2_LAYERS = pd.read_excel('../토양 특성/HWSD2_LAYERS.xlsx')
HWSD2_LAYERS.head()
# Out:
#    ID  HWSD2_SMU_ID  NSC_MU_SOURCE1  NSC_MU_SOURCE2 WISE30s_SMU_ID  \
# 0   1          1666             NaN             NaN     WD10001666
# 1   2          6309             NaN             NaN     WD10006309
# 2   3          1700             NaN             NaN     WD10001700
# 3   4          6310             NaN             NaN     WD10006310
# 4   5          6311             NaN             NaN     WD10006311
#
#    HWSD1_SMU_ID  COVERAGE  SEQUENCE  SHARE  NSC  ... CEC_SOIL CEC_CLAY  \
# 0          1666         4         1     70  NaN  ...        8       50
# 1          6309         4         1     50  NaN  ...        8       50
# 2          1700         4         1     60  NaN  ...        8       50
# 3          6310         4         1     30  NaN  ...        8       50
# 4          6311         4         1     50  NaN  ...        8       50
#
#   CEC_EFF TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND
# 0       4   5    71         0    4         0.0     2.9          1
# ...

# %%
HWSD2_LAYERS_2 = pd.read_excel('../토양 특성/HWSD2_LAYERS_2.xlsx')
HWSD2_LAYERS_2.head()
# Out:
#       ID  HWSD2_SMU_ID  NSC_MU_SOURCE1  NSC_MU_SOURCE2 WISE30s_SMU_ID  \
# 0  65534          4582             NaN             NaN     WD10004582
# 1  65535         26600             NaN             NaN     WD10026600
# 2  65536         31383             NaN             NaN     WD10031383
# 3  65537          3758             NaN             NaN     WD10003758
# 4  65538         18695             NaN             NaN     WD10018695
#
#    HWSD1_SMU_ID  COVERAGE  SEQUENCE  SHARE  NSC  ... CEC_SOIL CEC_CLAY  \
# 0          4582         4         3     10  NaN  ...       16       40
# 1         26600         3         1     80  NaN  ...       16       40
# 2         31383         3         2     49  NaN  ...       16       40
# 3          3758         4         3     20  NaN  ...       16       40
# 4         18695         3         1     60  NaN  ...       16       40
#
#   CEC_EFF TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND
# ...

# %%
HWSD2_LAYERS_3 = pd.read_excel('../토양 특성/HWSD2_LAYERS_3.xlsx')
HWSD2_LAYERS_3.head()
# Out:
#        ID  HWSD2_SMU_ID  NSC_MU_SOURCE1  NSC_MU_SOURCE2 WISE30s_SMU_ID  \
# 0  131067          7095             NaN             NaN     WD40007095
# 1  131068          7096             NaN             NaN     WD40007096
# 2  131069          7107             NaN             NaN     WD40007107
# 3  131070          7097             NaN             NaN     WD40007097
# 4  131071          8889             NaN             NaN     WD40008889
#
#    HWSD1_SMU_ID  COVERAGE  SEQUENCE  SHARE  NSC  ... CEC_SOIL CEC_CLAY  \
# 0          7095         1         1     90  NaN  ...       54       42
# 1          7096         1         1     90  NaN  ...       54       42
# 2          7107         1         1     90  NaN  ...       54       42
# 3          7097         1         1     90  NaN  ...       54       42
# 4          8889         1         2     10  NaN  ...       54       42
#
#   CEC_EFF TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND
# ...

# %%
HWSD2_LAYERS_4 = pd.read_excel('../토양 특성/HWSD2_LAYERS_4.xlsx')
HWSD2_LAYERS_4.head()
# Out:
#        ID  HWSD2_SMU_ID  NSC_MU_SOURCE1  NSC_MU_SOURCE2 WISE30s_SMU_ID  \
# 0  196600         10244             NaN             NaN     WD40010244
# 1  196601          9926             NaN             NaN     WD40009926
# 2  196602         10168             NaN             NaN     WD40010168
# 3  196603         10173             NaN             NaN     WD40010173
# 4  196604         10171             NaN             NaN     WD40010171
#
#    HWSD1_SMU_ID  COVERAGE  SEQUENCE  SHARE  NSC  ... CEC_SOIL CEC_CLAY  \
# 0         10244         1         2     40  NaN  ...       11       36
# 1          9926         1         1     55  NaN  ...       11       36
# 2         10168         1         3     20  NaN  ...       11       36
# 3         10173         1         4     10  NaN  ...       11       36
# 4         10171         1         2     25  NaN  ...       11       36
#
#   CEC_EFF TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND
# ...

# %%
HWSD2_LAYERS_5 = pd.read_excel('../토양 특성/HWSD2_LAYERS_5.xlsx')
HWSD2_LAYERS_5.head()
# Out:
#        ID  HWSD2_SMU_ID NSC_MU_SOURCE1 NSC_MU_SOURCE2 WISE30s_SMU_ID  \
# 0  262133          1684            NaN            NaN     WD20001684
# 1  262134          1685            NaN            NaN     WD20001685
# 2  262135          1683            NaN            NaN     WD20001683
# 3  262136          1682            NaN            NaN     WD20001682
# 4  262137          1681            NaN            NaN     WD20001681
#
#    HWSD1_SMU_ID  COVERAGE  SEQUENCE  SHARE  NSC  ... CEC_SOIL CEC_CLAY  \
# 0          1684         4         1     70  NaN  ...       13       80
# 1          1685         4         1     70  NaN  ...       13       80
# 2          1683         4         1     70  NaN  ...       13       80
# 3          1682         4         1     70  NaN  ...       13       80
# 4          1681         4         1     70  NaN  ...       13       80
#
#   CEC_EFF TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND
# ...

# %%
HWSD2_LAYERS_6 = pd.read_excel('../토양 특성/HWSD2_LAYERS_6.xlsx')
HWSD2_LAYERS_6.head()
# Out:
#        ID  HWSD2_SMU_ID NSC_MU_SOURCE1 NSC_MU_SOURCE2 WISE30s_SMU_ID  \
# 0  661746         36084            DMT            wen     WD10036084
# 1  661747         36084            DMT            wen     WD10036084
# 2  661748         36084            DMT            wen     WD10036084
# 3  661749         36084            DMT            wen     WD10036084
# 4  661750         36084            DMT            wen     WD10036084
#
#    HWSD1_SMU_ID  COVERAGE  SEQUENCE  SHARE  NSC  ... CEC_SOIL CEC_CLAY  \
# 0         36084         7         5     10  NaN  ...       -7       -7
# 1         36084         7         5     10  NaN  ...       -7       -7
# 2         36084         7         5     10  NaN  ...       -7       -7
# 3         36084         7         5     10  NaN  ...       -7       -7
# 4         36084         7         5     10  NaN  ...       -7       -7
#
#   CEC_EFF TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND
# ...

# %%
HWSD2_LAYERS_7 = pd.read_excel('../토양 특성/HWSD2_LAYERS_7.xlsx')
HWSD2_LAYERS_7.head()
# Out:
#        ID  HWSD2_SMU_ID NSC_MU_SOURCE1 NSC_MU_SOURCE2 WISE30s_SMU_ID  \
# 0  727279         47134   60_CE_4X_000   60_CE_4X_000     WD40047134
# 1  727280         47134   60_CE_4X_000   60_CE_4X_000     WD40047134
# 2  727281         47134   60_CE_4X_000   60_CE_4X_000     WD40047134
# 3  727282         47134   60_CE_4X_000   60_CE_4X_000     WD40047134
# 4  727283         47134   60_CE_4X_000   60_CE_4X_000     WD40047134
#
#    HWSD1_SMU_ID  COVERAGE  SEQUENCE  SHARE  NSC  ... CEC_SOIL CEC_CLAY  \
# 0         47134         8         1    100  NaN  ...       17       55
# 1         47134         8         1    100  NaN  ...       12       52
# 2         47134         8         1    100  NaN  ...       12       43
# 3         47134         8         1    100  NaN  ...       10       53
# 4         47134         8         1    100  NaN  ...       10       59
#
#   CEC_EFF TEB  BSAT  ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND
# ...

# %%
HWSD2_LAYERS_raw = pd.concat([HWSD2_LAYERS, HWSD2_LAYERS_2, HWSD2_LAYERS_3, HWSD2_LAYERS_4, HWSD2_LAYERS_5, HWSD2_LAYERS_6, HWSD2_LAYERS_7], axis=0)

# %%
HWSD2_LAYERS_raw.shape
# Out:
# (408841, 48)

# %%
HWSD2_LAYERS_raw = HWSD2_LAYERS_raw.drop_duplicates()

# %%
HWSD2_LAYERS_raw.shape
# Out:
# (408835, 48)

# %%
HWSD2_LAYERS_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 408835 entries, 0 to 15636
# Data columns (total 48 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ID              408835 non-null  int64
#  1   HWSD2_SMU_ID    408835 non-null  int64
#  2   NSC_MU_SOURCE1  108878 non-null  object
#  3   NSC_MU_SOURCE2  108843 non-null  object
#  4   WISE30s_SMU_ID  408835 non-null  object
#  5   HWSD1_SMU_ID    408835 non-null  int64
#  6   COVERAGE        408835 non-null  int64
#  7   SEQUENCE        408835 non-null  int64
#  8   SHARE           408835 non-null  int64
#  9   NSC             0 non-null       float64
#  10  WRB_PHASES      408825 non-null  object
#  11  WRB4            396594 non-null  object
#  12  WRB2            408835 non-null  object
#  13  FAO90           408835 non-null  object
#  14  ROOT_DEPTH      59917 non-null   float64
#  15  PHASE1          112809 non-null  float64
#  16  PHASE2          111029 non-null  float64
# ...

# %%
HWSD2_LAYERS_raw.reset_index(drop=True)
# Out:
#             ID  HWSD2_SMU_ID NSC_MU_SOURCE1 NSC_MU_SOURCE2 WISE30s_SMU_ID  \
# 0            1          1666            NaN            NaN     WD10001666
# 1            2          6309            NaN            NaN     WD10006309
# 2            3          1700            NaN            NaN     WD10001700
# 3            4          6310            NaN            NaN     WD10006310
# 4            5          6311            NaN            NaN     WD10006311
# ...        ...           ...            ...            ...            ...
# 408830  742911         49830   81_TA_0X_000   81_TA_0X_000     WD30049830
# 408831  742912         49830   81_TA_0X_000   81_TA_0X_000     WD30049830
# 408832  742913         49830   81_TA_0X_000   81_TA_0X_000     WD30049830
# 408833  742914         49830   81_TA_0X_000   81_TA_0X_000     WD30049830
# 408834  742915         49830   81_TA_0X_000   81_TA_0X_000     WD30049830
#
#         HWSD1_SMU_ID  COVERAGE  SEQUENCE  SHARE  NSC  ... CEC_SOIL CEC_CLAY  \
# ...

# %%
HWSD2_LAYERS_raw.to_csv('HWSD2_LAYERS_raw.csv')

# %%
HWSD2_SMU_1 = pd.read_excel('../토양 특성/HWSD2_SMU_1.xlsx')
HWSD2_SMU_1.head()
# Out:
#     ID  HWSD2_SMU_ID WISE30s_SMU_ID  HWSD1_SMU_ID  COVERAGE  SHARE  WRB4  \
# 0  669         12707     WD10012707         12707         3     40  ALfr
# 1  695         11825     WD30011825         11825         2    100  ALfr
# 2  696         11823     WD30011823         11823         2    100  ALfr
# 3  697         13458     WD30013458         13458         3    100  ALfr
# 4  698         11824     WD30011824         11824         2    100  ALfr
#
#   WRB_PHASES WRB2  WRB2_CODE  ... REF_BULK_DENSITY BULK_DENSITY  DRAINAGE  \
# 0       ALfr   AL          2  ...             1.63         1.35        MW
# 1       ALfr   AL          2  ...             1.76         1.44        MW
# 2       ALfr   AL          2  ...             1.76         1.44        MW
# 3       ALfr   AL          2  ...             1.76         1.44        MW
# 4       ALfr   AL          2  ...             1.76         1.44        MW
#
#    ROOT_DEPTH  AWC PHASE1  PHASE2  ROOTS  IL  ADD_PROP
# ...

# %%
HWSD2_SMU_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29538 entries, 0 to 29537
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                29538 non-null  int64
#  1   HWSD2_SMU_ID      29538 non-null  int64
#  2   WISE30s_SMU_ID    29538 non-null  object
#  3   HWSD1_SMU_ID      29538 non-null  int64
#  4   COVERAGE          29538 non-null  int64
#  5   SHARE             29538 non-null  int64
#  6   WRB4              27790 non-null  object
#  7   WRB_PHASES        29528 non-null  object
#  8   WRB2              27790 non-null  object
#  9   WRB2_CODE         29538 non-null  int64
#  10  FAO90             29538 non-null  object
#  11  KOPPEN            29538 non-null  object
#  12  TEXTURE_USDA      28748 non-null  float64
#  13  REF_BULK_DENSITY  28748 non-null  float64
#  14  BULK_DENSITY      29538 non-null  float64
#  15  DRAINAGE          28698 non-null  object
# ...

# %%
HWSD2_SMU_1[HWSD2_SMU_1.HWSD2_SMU_ID==361]
# Out:
#          ID  HWSD2_SMU_ID WISE30s_SMU_ID  HWSD1_SMU_ID  COVERAGE  SHARE  WRB4  \
# 2297  36131           361     WD20000361           361         4     50  CLha
#
#      WRB_PHASES WRB2  WRB2_CODE  ... REF_BULK_DENSITY BULK_DENSITY  DRAINAGE  \
# 2297       CLkk   CL          7  ...             1.68         1.45        MW
#
#       ROOT_DEPTH  AWC PHASE1  PHASE2  ROOTS  IL  ADD_PROP
# 2297           1  150    1.0     NaN    NaN NaN       0.0
#
# [1 rows x 23 columns]

# %%
HWSD2_SMU_1= HWSD2_SMU_1.drop_duplicates()

# %%
HWSD2_SMU_1.to_csv('HWSD2_SMU.csv')

# %% [markdown]
# # 전체 layer 있는 DATA

# %%
merge_data = pd.merge(HWSD2_SMU_1,HWSD2_LAYERS_raw,how = 'left', on='HWSD2_SMU_ID')
merge_data.head()
# Out:
#    ID_x  HWSD2_SMU_ID WISE30s_SMU_ID_x  HWSD1_SMU_ID_x  COVERAGE_x  SHARE_x  \
# 0   669         12707       WD10012707           12707           3       40
# 1   669         12707       WD10012707           12707           3       40
# 2   669         12707       WD10012707           12707           3       40
# 3   669         12707       WD10012707           12707           3       40
# 4   669         12707       WD10012707           12707           3       40
#
#   WRB4_x WRB_PHASES_x WRB2_x  WRB2_CODE  ... CEC_SOIL CEC_CLAY  CEC_EFF  TEB  \
# 0   ALfr         ALfr     AL          2  ...        8       46        6    5
# 1   ALfr         ALfr     AL          2  ...        9       41        4    4
# 2   ALfr         ALfr     AL          2  ...       11       39        5    4
# 3   ALfr         ALfr     AL          2  ...       13       32        6    4
# 4   ALfr         ALfr     AL          2  ...       14       32        7    4
#
# ...

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408835 entries, 0 to 408834
# Data columns (total 70 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID_x              408835 non-null  int64
#  1   HWSD2_SMU_ID      408835 non-null  int64
#  2   WISE30s_SMU_ID_x  408835 non-null  object
#  3   HWSD1_SMU_ID_x    408835 non-null  int64
#  4   COVERAGE_x        408835 non-null  int64
#  5   SHARE_x           408835 non-null  int64
#  6   WRB4_x            396599 non-null  object
#  7   WRB_PHASES_x      408632 non-null  object
#  8   WRB2_x            396599 non-null  object
#  9   WRB2_CODE         408835 non-null  int64
#  10  FAO90_x           408835 non-null  object
#  11  KOPPEN            408835 non-null  object
#  12  TEXTURE_USDA_x    401233 non-null  float64
#  13  REF_BULK_DENSITY  401233 non-null  float64
#  14  BULK_DENSITY      408835 non-null  float64
#  15  DRAINAGE_x        400862 non-null  object
# ...

# %%
merge_data.columns
# Out:
# Index(['ID_x', 'HWSD2_SMU_ID', 'WISE30s_SMU_ID_x', 'HWSD1_SMU_ID_x',
#        'COVERAGE_x', 'SHARE_x', 'WRB4_x', 'WRB_PHASES_x', 'WRB2_x',
#        'WRB2_CODE', 'FAO90_x', 'KOPPEN', 'TEXTURE_USDA_x', 'REF_BULK_DENSITY',
#        'BULK_DENSITY', 'DRAINAGE_x', 'ROOT_DEPTH_x', 'AWC_x', 'PHASE1_x',
#        'PHASE2_x', 'ROOTS_x', 'IL_x', 'ADD_PROP_x', 'ID_y', 'NSC_MU_SOURCE1',
#        'NSC_MU_SOURCE2', 'WISE30s_SMU_ID_y', 'HWSD1_SMU_ID_y', 'COVERAGE_y',
#        'SEQUENCE', 'SHARE_y', 'NSC', 'WRB_PHASES_y', 'WRB4_y', 'WRB2_y',
#        'FAO90_y', 'ROOT_DEPTH_y', 'PHASE1_y', 'PHASE2_y', 'ROOTS_y', 'IL_y',
#        'SWR', 'DRAINAGE_y', 'AWC_y', 'ADD_PROP_y', 'LAYER', 'TOPDEP', 'BOTDEP',
#        'COARSE', 'SAND', 'SILT', 'CLAY', 'TEXTURE_USDA_y', 'TEXTURE_SOTER',
#        'BULK', 'REF_BULK', 'ORG_CARBON', 'PH_WATER', 'TOTAL_N', 'CN_RATIO',
#        'CEC_SOIL', 'CEC_CLAY', 'CEC_EFF', 'TEB', 'BSAT', 'ALUM_SAT', 'ESP',
#        'TCARBON_EQ', 'GYPSUM', 'ELEC_COND'],
#       dtype='object')

# %%
merge_data.loc[merge_data.HWSD2_SMU_ID == 361]
# Out:
#         ID_x  HWSD2_SMU_ID WISE30s_SMU_ID_x  HWSD1_SMU_ID_x  COVERAGE_x  \
# 40467  36131           361       WD20000361             361           4
# 40468  36131           361       WD20000361             361           4
# 40469  36131           361       WD20000361             361           4
# 40470  36131           361       WD20000361             361           4
# 40471  36131           361       WD20000361             361           4
# 40472  36131           361       WD20000361             361           4
# 40473  36131           361       WD20000361             361           4
# 40474  36131           361       WD20000361             361           4
# 40475  36131           361       WD20000361             361           4
# 40476  36131           361       WD20000361             361           4
# 40477  36131           361       WD20000361             361           4
# 40478  36131           361       WD20000361             361           4
# ...

# %%
merge_data['LAYER'].value_counts()
# Out:
# LAYER
# D1    58405
# D2    58405
# D3    58405
# D4    58405
# D5    58405
# D6    58405
# D7    58405
# Name: count, dtype: int64

# %%
merge_data['SEQUENCE'].value_counts()
# Out:
# SEQUENCE
# 1     206766
# 2     105735
# 3      58303
# 4      24500
# 5       9072
# 6       3199
# 7        700
# 8        301
# 9        133
# 10        77
# 11        28
# 12        21
# Name: count, dtype: int64

# %% [markdown]
# # Depth_layer 1 까지만 있는 DATA

# %%
merge_data_2 = pd.merge(HWSD2_SMU_1,HWSD2_LAYERS_raw,how = 'inner', left_on='ID',right_on='ID')
merge_data_2.head()
# Out:
#     ID  HWSD2_SMU_ID_x WISE30s_SMU_ID_x  HWSD1_SMU_ID_x  COVERAGE_x  SHARE_x  \
# 0  669           12707       WD10012707           12707           3       40
# 1  695           11825       WD30011825           11825           2      100
# 2  696           11823       WD30011823           11823           2      100
# 3  697           13458       WD30013458           13458           3      100
# 4  698           11824       WD30011824           11824           2      100
#
#   WRB4_x WRB_PHASES_x WRB2_x  WRB2_CODE  ... CEC_SOIL CEC_CLAY  CEC_EFF  TEB  \
# 0   ALfr         ALfr     AL          2  ...        8       46        6    5
# 1   ALfr         ALfr     AL          2  ...        9       20        6    4
# 2   ALfr         ALfr     AL          2  ...        9       20        6    4
# 3   ALfr         ALfr     AL          2  ...        9       20        6    4
# 4   ALfr         ALfr     AL          2  ...        9       20        6    4
#
# ...

# %%
merge_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29538 entries, 0 to 29537
# Data columns (total 70 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                29538 non-null  int64
#  1   HWSD2_SMU_ID_x    29538 non-null  int64
#  2   WISE30s_SMU_ID_x  29538 non-null  object
#  3   HWSD1_SMU_ID_x    29538 non-null  int64
#  4   COVERAGE_x        29538 non-null  int64
#  5   SHARE_x           29538 non-null  int64
#  6   WRB4_x            27790 non-null  object
#  7   WRB_PHASES_x      29528 non-null  object
#  8   WRB2_x            27790 non-null  object
#  9   WRB2_CODE         29538 non-null  int64
#  10  FAO90_x           29538 non-null  object
#  11  KOPPEN            29538 non-null  object
#  12  TEXTURE_USDA_x    28748 non-null  float64
#  13  REF_BULK_DENSITY  28748 non-null  float64
#  14  BULK_DENSITY      29538 non-null  float64
#  15  DRAINAGE_x        28698 non-null  object
# ...

# %%
merge_data_2.loc[merge_data_2. HWSD2_SMU_ID_x == 361]
# Out:
#          ID  HWSD2_SMU_ID_x WISE30s_SMU_ID_x  HWSD1_SMU_ID_x  COVERAGE_x  \
# 2297  36131             361       WD20000361             361           4
#
#       SHARE_x WRB4_x WRB_PHASES_x WRB2_x  WRB2_CODE  ... CEC_SOIL CEC_CLAY  \
# 2297       50   CLha         CLkk     CL          7  ...       14       67
#
#       CEC_EFF  TEB  BSAT ALUM_SAT  ESP  TCARBON_EQ  GYPSUM  ELEC_COND
# 2297       38   38   100        0    2        13.9     0.2          1
#
# [1 rows x 70 columns]

# %%
merge_data_2['LAYER'].value_counts()
# Out:
# LAYER
# D1    29538
# Name: count, dtype: int64

# %%
merge_data_2['SEQUENCE'].value_counts()
# Out:
# SEQUENCE
# 1    29538
# Name: count, dtype: int64

# %%
merge_data_2.columns
# Out:
# Index(['ID', 'HWSD2_SMU_ID_x', 'WISE30s_SMU_ID_x', 'HWSD1_SMU_ID_x',
#        'COVERAGE_x', 'SHARE_x', 'WRB4_x', 'WRB_PHASES_x', 'WRB2_x',
#        'WRB2_CODE', 'FAO90_x', 'KOPPEN', 'TEXTURE_USDA_x', 'REF_BULK_DENSITY',
#        'BULK_DENSITY', 'DRAINAGE_x', 'ROOT_DEPTH_x', 'AWC_x', 'PHASE1_x',
#        'PHASE2_x', 'ROOTS_x', 'IL_x', 'ADD_PROP_x', 'HWSD2_SMU_ID_y',
#        'NSC_MU_SOURCE1', 'NSC_MU_SOURCE2', 'WISE30s_SMU_ID_y',
#        'HWSD1_SMU_ID_y', 'COVERAGE_y', 'SEQUENCE', 'SHARE_y', 'NSC',
#        'WRB_PHASES_y', 'WRB4_y', 'WRB2_y', 'FAO90_y', 'ROOT_DEPTH_y',
#        'PHASE1_y', 'PHASE2_y', 'ROOTS_y', 'IL_y', 'SWR', 'DRAINAGE_y', 'AWC_y',
#        'ADD_PROP_y', 'LAYER', 'TOPDEP', 'BOTDEP', 'COARSE', 'SAND', 'SILT',
#        'CLAY', 'TEXTURE_USDA_y', 'TEXTURE_SOTER', 'BULK', 'REF_BULK',
#        'ORG_CARBON', 'PH_WATER', 'TOTAL_N', 'CN_RATIO', 'CEC_SOIL', 'CEC_CLAY',
#        'CEC_EFF', 'TEB', 'BSAT', 'ALUM_SAT', 'ESP', 'TCARBON_EQ', 'GYPSUM',
#        'ELEC_COND'],
# ...

# %% [markdown]
# ---

# %% [markdown]
# # 나라, 지역 정보 찾기

# %%
import geopandas as gpd

file_path = "C:/Users/user/OneDrive/문서/사용자 지정 Office 서식 파일/바탕 화면/ML_PRJ/ML_wine/GLOSIS 글로벌 토양 특성/country.shp"
gdf = gpd.read_file(file_path)

# GeoDataFrame을 pandas DataFrame으로 변환
# df = gdf.drop(columns='geometry')  # 지오메트리 컬럼을 제외할 경우
df = gdf  # 지오메트리 컬럼 포함

# 데이터 확인
df.head()
# Out:
#                                             geometry
# 0  MULTILINESTRING ((180.000 -84.426, 180.000 -89...
# 1  LINESTRING (-69.872 12.441, -69.871 12.437, -6...
# 2  LINESTRING (74.890 37.234, 74.889 37.231, 74.8...
# 3  LINESTRING (61.274 35.605, 61.276 35.597, 61.2...
# 4  LINESTRING (74.565 37.031, 74.523 37.019, 74.5...

# %%
# !pip install geopy
# Out:
# ...
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --------- ------------------------------ 30.7/125.4 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 2.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB ? eta 0:00:00
# ...

# %%
import geopandas as gpd
from geopy.geocoders import GoogleV3
from shapely.geometry import Point

# Google Geocoding 서비스 초기화
API_KEY = ''
geolocator = GoogleV3(api_key=API_KEY)

# GeoDataFrame에서 첫 번째 좌표 가져오기 (예제)
geo_country = df.copy()

def get_country_region(geometry):
    if geometry.geom_type == 'LineString':
        point = geometry.interpolate(0.5)  # 중앙 지점을 사용
    elif geometry.geom_type == 'MultiLineString':
        point = geometry.interpolate(0.5)  # 첫 번째 LineString 사용

    location = geolocator.reverse((point.y, point.x))
    if location:
        address = location.raw.get('address_components', [])
        country = state = None
        for component in address:
            if 'country' in component['types']:
                country = component['long_name']
            elif 'administrative_area_level_1' in component['types']:
                state = component['long_name']
        return country, state

# 각 지오메트리의 나라와 지역 정보 가져오기
geo_country['country_region'] = geo_country['geometry'].apply(get_country_region)
geo_country
# Out:
#                                               geometry  \
# 0    MULTILINESTRING ((180.000 -84.426, 180.000 -89...
# 1    LINESTRING (-69.872 12.441, -69.871 12.437, -6...
# 2    LINESTRING (74.890 37.234, 74.889 37.231, 74.8...
# 3    LINESTRING (61.274 35.605, 61.276 35.597, 61.2...
# 4    LINESTRING (74.565 37.031, 74.523 37.019, 74.5...
# ..                                                 ...
# 534  MULTILINESTRING ((121.605 -10.606, 121.612 -10...
# 535  LINESTRING (124.043 -9.336, 124.052 -9.335, 12...
# 536  LINESTRING (34.269 31.221, 34.334 31.265, 34.3...
# 537  LINESTRING (35.476 31.493, 35.408 31.495, 35.4...
# 538  LINESTRING (28.426 10.167, 28.435 10.167, 28.4...
#
#                       country_region
# 0                       (None, None)
# 1                      (Aruba, None)
# 2                       (None, None)
# 3               (Afghanistan, Herat)
# 4                       (None, None)
# ..                               ...
# ...

# %%
import pandas as pd
climate_lo = pd.read_csv('../dfLocation_1.csv')
climate_lo
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8976\831281960.py:2: DtypeWarning: Columns (18,20,34,36,46,48,54,60,86,94,104,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   climate_lo = pd.read_csv('../dfLocation_1.csv')
#       Unnamed: 0      STATION     DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0              0  ACW00011604  1949-01  17.11667  -61.78333       10.1
# 1              1  ACW00011647  1957-09  17.13333  -61.78333       19.2
# 2              2  AE000041196  1944-04  25.33300   55.51700       34.0
# 3              3  AEM00041194  1983-01  25.25500   55.36400       10.4
# 4              4  AEM00041217  1983-06  24.43300   54.65100       26.8
# ...          ...          ...      ...       ...        ...        ...
# 9995        9995  ASN00051026  1905-09 -31.56290  146.71810      215.0
# 9996        9996  ASN00051027  1928-02 -31.10000  147.30000        NaN
# 9997        9997  ASN00051028  1899-08 -31.51670  147.38330      177.0
# ...

# %%
lo = climate_lo[['NAME','LATITUDE','LONGITUDE']]
lo
# Out:
#                              NAME  LATITUDE  LONGITUDE
# 0     ST JOHNS COOLIDGE FIELD, AC  17.11667  -61.78333
# 1                    ST JOHNS, AC  17.13333  -61.78333
# 2         SHARJAH INTER. AIRP, AE  25.33300   55.51700
# 3         DUBAI INTERNATIONAL, AE  25.25500   55.36400
# 4     ABU DHABI INTERNATIONAL, AE  24.43300   54.65100
# ...                           ...       ...        ...
# 9995           HERMIDALE TANK, AS -31.56290  146.71810
# 9996                ILLABUNDA, AS -31.10000  147.30000
# 9997            NYNGAN KALUGA, AS -31.51670  147.38330
# 9998       NYNGAN MERRYANBONE, AS -31.43330  147.43330
# 9999         MIANDETTA TYRONE, AS -31.60330  146.94370
#
# [10000 rows x 3 columns]

# %%
soil_lo = pd.read_csv('soil_mapping_data_2.csv')
soil_lo.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 soil_lo = pd.read_csv('soil_mapping_data_2.csv')
#       2 soil_lo.head()
#
# File c:\Users\user\miniconda3\envs\ds_study\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
soil_lo = soil_lo[['Longitude','Latitude','Soil Mapping Unit']]
soil_lo
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 soil_lo = soil_lo[['Longitude','Latitude','Soil Mapping Unit']]
#       2 soil_lo
#
# File c:\Users\user\miniconda3\envs\ds_study\lib\site-packages\pandas\core\frame.py:3773, in DataFrame.__getitem__(self, key)
#    3770 if getattr(indexer, "dtype", None) == bool:
#    3771     indexer = np.where(indexer)[0]
# -> 3773 data = self._take_with_is_copy(indexer, axis=1)
#    3775 if is_single_key:
#    3776     # What does looking for a single key in a non-unique index return?
#    3777     # The behavior is inconsistent. It returns a Series, except when
#    3778     # - the key itself is repeated (test on data.shape, #9519), or
#    3779     # - we have a MultiIndex on columns (test on self.columns, #21309)
#    3780     if data.shape[1] == 1 and not isinstance(self.columns, MultiIndex):
# ...

# %%
soil_lo['Longitude'] = round(soil_lo['Longitude'],4)
soil_lo['Latitude'] = round(soil_lo['Latitude'],4)

# %%
soil_lo.head()
# Out:
#    Longitude  Latitude  Soil Mapping Unit
# 0     -35.74     83.62               6998
# 1     -35.73     83.62               6998
# 2     -35.72     83.62               6998
# 3     -35.72     83.62               6998
# 4     -35.71     83.62               6998

# %%
lat = round(lo.loc[0,'LATITUDE'],2)
lng = round(lo.loc[0,'LONGITUDE'],2)
lo.loc[0,'NAME']
# Out:
# 'ST JOHNS COOLIDGE FIELD, AC'

# %%
soil_lo.loc[(soil_lo.Latitude == lat) & (soil_lo.Longitude == lng)]
# Out:
#            Longitude  Latitude  Soil Mapping Unit
# 158031265     -61.78     17.12              12001
# 158043803     -61.78     17.12              12001
# 158043804     -61.78     17.12              12001

# %%
from tqdm.notebook import tqdm

# for idx,row in tqdm(lo.iterrows()):
#     lat = round(lo.loc[idx,'LATITUDE'],2)
#     lng = round(lo.loc[idx,'LONGITUDE'],2)
#     df = soil_lo.loc[(soil_lo.Latitude == lat) & (soil_lo.Longitude == lng)]
#     df['Country'] = str(lo.loc[idx,'NAME'])

#     if idx == 0:
#         country_df = df
#     else:
#         country_df = pd.concat([country_df,df],axis=1)

country_df = pd.DataFrame()

for idx, row in tqdm(lo.iterrows(), total=lo.shape[0]):
    lat = round(row['LATITUDE'], 2)
    lng = round(row['LONGITUDE'], 2)
    df = soil_lo.loc[(soil_lo['Latitude'] == lat) & (soil_lo['Longitude'] == lng)].copy()
    df['Country'] = lo.loc[idx, 'NAME']

    if country_df.empty:
        country_df = df
    else:
        country_df = pd.concat([country_df, df], axis=0)

country_df.reset_index(drop=True, inplace=True)

country_df
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#        Longitude  Latitude  Soil Mapping Unit                      Country
# 0         -61.78     17.12              12001  ST JOHNS COOLIDGE FIELD, AC
# 1         -61.78     17.12              12001  ST JOHNS COOLIDGE FIELD, AC
# 2         -61.78     17.12              12001  ST JOHNS COOLIDGE FIELD, AC
# 3         -61.78     17.13              12001                 ST JOHNS, AC
# 4          55.52     25.33               3043      SHARJAH INTER. AIRP, AE
# ...          ...       ...                ...                          ...
# 14653     147.38    -31.52               6090            NYNGAN KALUGA, AS
# 14654     147.38    -31.52               6090            NYNGAN KALUGA, AS
# 14655     147.43    -31.43               6090       NYNGAN MERRYANBONE, AS
# 14656     147.43    -31.43               6090       NYNGAN MERRYANBONE, AS
# 14657     146.94    -31.60               6189         MIANDETTA TYRONE, AS
#
# [14658 rows x 4 columns]

# %%
country_df.to_csv('country_df.csv')

# %%
country_df.isnull().sum()
# Out:
# Longitude            0
# Latitude             0
# Soil Mapping Unit    0
# Country              0
# dtype: int64

# %%
country_df[country_df.duplicated()]
# Out:
#        Longitude  Latitude  Soil Mapping Unit                      Country
# 1         -61.78     17.12              12001  ST JOHNS COOLIDGE FIELD, AC
# 2         -61.78     17.12              12001  ST JOHNS COOLIDGE FIELD, AC
# 5          55.52     25.33               3043      SHARJAH INTER. AIRP, AE
# 10         69.02     35.32              33394             NORTH SALANG, AF
# 13         69.21     34.57               7001      KABUL INTERNATIONAL, AF
# ...          ...       ...                ...                          ...
# 14649     146.72    -31.56               6189           HERMIDALE TANK, AS
# 14652     147.38    -31.52               6090            NYNGAN KALUGA, AS
# 14653     147.38    -31.52               6090            NYNGAN KALUGA, AS
# 14654     147.38    -31.52               6090            NYNGAN KALUGA, AS
# 14656     147.43    -31.43               6090       NYNGAN MERRYANBONE, AS
#
# [4510 rows x 4 columns]

# %%
country_df = country_df.drop_duplicates()

# %%
country_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10148 entries, 0 to 14657
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Longitude          10148 non-null  float64
#  1   Latitude           10148 non-null  float64
#  2   Soil Mapping Unit  10148 non-null  int64
#  3   Country            10148 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 396.4+ KB

# %%
country_df.groupby('Country')['Soil Mapping Unit'].count().to_frame()
# Out:
#                           Soil Mapping Unit
# Country
# AASUFOU, AS AQ                            1
# ABBOT POINT BULKCOAL, AS                  1
# ABBOTSFORD, AS                            1
# ABBOTTS, AS                               1
# ABERCORN TM, AS                           1
# ...                                     ...
# ZATTAS ALERT, AS                          1
# ZENATA, AG                                1
# ZIG ZIG STATION, AS                       1
# ZILLMERE POST OFFICE, AS                  1
# ZONIA DOWNS, AS                           1
#
# [9522 rows x 1 columns]

# %%
climate_lo = pd.read_csv('../dfLocation_2.csv')
lo = climate_lo[['NAME','LATITUDE','LONGITUDE']]
lo
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8976\272517530.py:1: DtypeWarning: Columns (20,22,28,30,32,36,40,42,44,46,48,52,54,56,58,62,66,68,74,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   climate_lo = pd.read_csv('../dfLocation_2.csv')
#                        NAME  LATITUDE  LONGITUDE
# 0       NYNGAN CANONBAR, AS  -31.6395   147.3160
# 1        MOUNT TENANDRA, AS  -31.2000   148.7000
# 2         NYNGAN MUDALL, AS  -31.8576   147.1343
# 3     WARREN MUMBLEBONE, AS  -31.4986   147.6865
# 4            MUNGERIBAR, AS  -32.1500   148.1000
# ...                     ...       ...        ...
# 9995        VIDAL RAMOS, BR  -27.3900   -49.3700
# 9996      LEOBERTO LEAL, BR  -27.5100   -49.2900
# 9997     BOCAINA DO SUL, BR  -27.7400   -49.9400
# 9998           SALTINHO, BR  -27.6800   -49.3700
# 9999           BOTUVERA, BR  -27.1800   -49.0700
#
# [10000 rows x 3 columns]

# %%
country_df_2 = pd.DataFrame()

for idx, row in tqdm(lo.iterrows(), total=lo.shape[0]):
    lat = round(row['LATITUDE'], 4)
    lng = round(row['LONGITUDE'], 4)
    df = soil_lo.loc[(soil_lo['Latitude'] == lat) & (soil_lo['Longitude'] == lng)].copy()
    df['Country'] = lo.loc[idx, 'NAME']

    if country_df_2.empty:
        country_df_2 = df
    else:
        country_df_2 = pd.concat([country_df_2, df], axis=0)

country_df_2.reset_index(drop=True, inplace=True)

country_df_2
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#       Longitude  Latitude  Soil Mapping Unit                    Country
# 0        -49.63    -27.21               7001    RIO DO SUL NOVO PCD, BR
# 1        -49.83    -27.41               7001             AGROLANDIA, BR
# 2        -49.09    -27.20              12810      BOTUVERA MONTANTE, BR
# 3        -49.33    -27.33              12677           SALSEIRO PCD, BR
# 4        -50.75    -27.90              12644      CAMPO BELO DO SUL, BR
# ...         ...       ...                ...                        ...
# 6941     -72.90     45.30               3458             FARNHAM, QC CA
# 6942     -73.00     45.80               3070              FLEURY, QC CA
# 6943     -71.95     45.20               4964              HATLEY, QC CA
# 6944     -71.45     45.45               3458  ISLAND BROOK NORTH, QC CA
# 6945     -71.25     45.40               3458           LA PATRIE, QC CA
#
# [6946 rows x 4 columns]

# %%
country_df_2.to_csv('country_df_2.csv')

# %%
climate_lo = pd.read_csv('../dfLocation_3.csv')
lo = climate_lo[['NAME','LATITUDE','LONGITUDE']]
lo
# Out:
#                           NAME  LATITUDE  LONGITUDE
# 0      RIO DO SUL NOVO PCD, BR  -27.2100   -49.6300
# 1               AGROLANDIA, BR  -27.4100   -49.8300
# 2        BOTUVERA MONTANTE, BR  -27.2000   -49.0900
# 3             SALSEIRO PCD, BR  -27.3300   -49.3300
# 4        CAMPO BELO DO SUL, BR  -27.9000   -50.7500
# ...                        ...       ...        ...
# 9995  MACDONALD COLLEGE, QC CA   45.4167   -73.9333
# 9996              MAGOG, QC CA   45.2667   -72.1167
# 9997            MANSEAU, QC CA   46.3333   -71.9833
# 9998         MAPLE LEAF, QC CA   45.3333   -71.5000
# 9999    MAPLE LEAF EAST, QC CA   45.3333   -71.4000
#
# [10000 rows x 3 columns]

# %%
country_df_3 = pd.DataFrame()

for idx, row in tqdm(lo.iterrows(), total=lo.shape[0]):
    lat = round(row['LATITUDE'], 4)
    lng = round(row['LONGITUDE'], 4)
    df = soil_lo.loc[(soil_lo['Latitude'] == lat) & (soil_lo['Longitude'] == lng)].copy()
    df['Country'] = lo.loc[idx, 'NAME']

    if country_df_3.empty:
        country_df_3 = df
    else:
        country_df_3 = pd.concat([country_df_3, df], axis=0)

country_df_3.reset_index(drop=True, inplace=True)

country_df_3
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#       Longitude  Latitude  Soil Mapping Unit                    Country
# 0        -49.63    -27.21               7001    RIO DO SUL NOVO PCD, BR
# 1        -49.83    -27.41               7001             AGROLANDIA, BR
# 2        -49.09    -27.20              12810      BOTUVERA MONTANTE, BR
# 3        -49.33    -27.33              12677           SALSEIRO PCD, BR
# 4        -50.75    -27.90              12644      CAMPO BELO DO SUL, BR
# ...         ...       ...                ...                        ...
# 6941     -72.90     45.30               3458             FARNHAM, QC CA
# 6942     -73.00     45.80               3070              FLEURY, QC CA
# 6943     -71.95     45.20               4964              HATLEY, QC CA
# 6944     -71.45     45.45               3458  ISLAND BROOK NORTH, QC CA
# 6945     -71.25     45.40               3458           LA PATRIE, QC CA
#
# [6946 rows x 4 columns]

# %%
country_df_3.to_csv('country_df_3.csv')

# %%
climate_lo = pd.read_csv('../dfLocation_4.csv')
lo = climate_lo[['NAME','LATITUDE','LONGITUDE']]
lo
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8976\1615767949.py:1: DtypeWarning: Columns (76,78,80,98,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   climate_lo = pd.read_csv('../dfLocation_4.csv')
#                          NAME  LATITUDE  LONGITUDE
# 0     MAPLE LEAF SOUTH, QC CA   45.3167   -71.4667
# 1           MARIEVILLE, QC CA   45.4000   -73.1333
# 2          MARTINVILLE, QC CA   45.3000   -71.7333
# 3             MCTAVISH, QC CA   45.5000   -73.5833
# 4           MEGANTIC A, QC CA   45.5833   -70.8667
# ...                       ...       ...        ...
# 9995            TOMAKOMAI, JA   42.6170   141.5500
# 9996              URAKAWA, JA   42.1670   142.7830
# 9997               ESASHI, JA   41.8670   140.1170
# 9998             HAKODATE, JA   41.8170   140.7500
# 9999              KUTCHAN, JA   42.9000   140.7500
#
# [10000 rows x 3 columns]

# %%
country_df_4 = pd.DataFrame()

for idx, row in tqdm(lo.iterrows(), total=lo.shape[0]):
    lat = round(row['LATITUDE'], 4)
    lng = round(row['LONGITUDE'], 4)
    df = soil_lo.loc[(soil_lo['Latitude'] == lat) & (soil_lo['Longitude'] == lng)].copy()
    df['Country'] = lo.loc[idx, 'NAME']

    if country_df_4.empty:
        country_df_4 = df
    else:
        country_df_4 = pd.concat([country_df_4, df], axis=0)

country_df_4.reset_index(drop=True, inplace=True)

country_df_4
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#       Longitude  Latitude  Soil Mapping Unit                          Country
# 0        -71.15     45.45               3458             MONT MEGANTIC, QC CA
# 1        -71.75     46.20               4964              PLESSISVILLE, QC CA
# 2        -73.75     45.50               7001            POSTE SARAGUAY, QC CA
# 3        -73.50     45.70               4653      RIVIERE DES PRAIRIES, QC CA
# 4        -71.25     46.15               3458  ST ANTOINE DE PONTBRIAND, QC CA
# ...         ...       ...                ...                              ...
# 6801      -4.02      5.32               7001                ABIDJAN VILLE, IV
# 6802      -3.30      5.30               1188                       ADIAKE, IV
# 6803      46.05     32.17               3628                   KUT AL HAI, IZ
# 6804      46.05     32.17               3628                   KUT AL HAI, IZ
# ...

# %%
country_df_4.to_csv('country_df_4.csv')

# %%
climate_lo = pd.read_csv('../dfLocation_5.csv')
lo = climate_lo[['NAME','LATITUDE','LONGITUDE']]
lo
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8976\2623880856.py:1: DtypeWarning: Columns (70,76,78,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   climate_lo = pd.read_csv('../dfLocation_5.csv')
#                    NAME  LATITUDE  LONGITUDE
# 0          MOMBETSU, JA    44.350    143.350
# 1             HIROO, JA    42.300    143.317
# 2           OFUNATO, JA    39.067    141.717
# 3            SHINJO, JA    38.750    140.317
# 4         WAKAMATSU, JA    37.483    139.917
# ...                 ...       ...        ...
# 9995  GROBLERSPLAAS, SF   -23.020     29.920
# 9996       MAASBULT, SF   -23.470     29.880
# 9997      ELIM HOSP, SF   -23.170     30.070
# 9998  GOEDEHOOP BOS, SF   -23.070     30.130
# 9999    BONTFONTEIN, SF   -23.350     30.150
#
# [10000 rows x 3 columns]

# %%
country_df_5 = pd.DataFrame()

for idx, row in tqdm(lo.iterrows(), total=lo.shape[0]):
    lat = round(row['LATITUDE'], 4)
    lng = round(row['LONGITUDE'], 4)
    df = soil_lo.loc[(soil_lo['Latitude'] == lat) & (soil_lo['Longitude'] == lng)].copy()
    df['Country'] = lo.loc[idx, 'NAME']

    if country_df_5.empty:
        country_df_5 = df
    else:
        country_df_5 = pd.concat([country_df_5, df], axis=0)

country_df_5.reset_index(drop=True, inplace=True)
country_df_5.to_csv('country_df_5.csv')
country_df_5
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#       Longitude  Latitude  Soil Mapping Unit            Country
# 0        143.35     44.35               7001       MOMBETSU, JA
# 1        140.35     38.25               7001       YAMAGATA, JA
# 2        140.90     36.95               7001        ONAHAMA, JA
# 3        136.90     37.40               7001         WAJIMA, JA
# 4        137.05     36.80               7001        FUSHIKI, JA
# ...         ...       ...                ...                ...
# 3633      29.88    -23.47              28731       MAASBULT, SF
# 3634      30.07    -23.17              28277      ELIM HOSP, SF
# 3635      30.13    -23.07              28256  GOEDEHOOP BOS, SF
# 3636      30.13    -23.07              28256  GOEDEHOOP BOS, SF
# 3637      30.15    -23.35              28498    BONTFONTEIN, SF
#
# [3638 rows x 4 columns]

# %%
climate_lo = pd.read_csv('../dfLocation_6.csv')
lo = climate_lo[['NAME','LATITUDE','LONGITUDE']]
lo
# Out:
#                             NAME   LATITUDE   LONGITUDE
# 0       ESTES PARK 2.0 NE, CO US  40.390383 -105.491471
# 1     FORT COLLINS 1.8 SW, CO US  40.534990 -105.089750
# 2         TIMNATH 1.8 SSE, CO US  40.507750 -104.965240
# 3         LIVERMORE 4.2 N, CO US  40.810340 -105.215840
# 4          LAPORTE 1.9 NW, CO US  40.635710 -105.159860
# ...                          ...        ...         ...
# 9995      WEYMOUTH 2.8 NW, MA US  42.244574  -70.956462
# 9996       WEYMOUTH 2.3 N, MA US  42.243336  -70.954796
# 9997     WESTWOOD 1.1 WSW, MA US  42.208230  -71.235180
# 9998       DEDHAM 1.8 ESE, MA US  42.234965  -71.147056
# 9999       MILLIS 1.4 ENE, MA US  42.179660  -71.333000
#
# [10000 rows x 3 columns]

# %%
country_df_6 = pd.DataFrame()

for idx, row in tqdm(lo.iterrows(), total=lo.shape[0]):
    lat = round(row['LATITUDE'], 4)
    lng = round(row['LONGITUDE'], 4)
    df = soil_lo.loc[(soil_lo['Latitude'] == lat) & (soil_lo['Longitude'] == lng)].copy()
    df['Country'] = lo.loc[idx, 'NAME']

    if country_df_6.empty:
        country_df_6 = df
    else:
        country_df_6 = pd.concat([country_df_6, df], axis=0)

country_df_6.reset_index(drop=True, inplace=True)
country_df_6.to_csv('country_df_6.csv')
country_df_6
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#     Longitude  Latitude  Soil Mapping Unit                       Country
# 0     -105.62     39.27               4679      JEFFERSON 12.1 SE, CO US
# 1     -105.62     39.27               4679      JEFFERSON 12.1 SE, CO US
# 2     -105.62     39.27               4679      JEFFERSON 12.1 SE, CO US
# 3     -105.62     39.27               4679      JEFFERSON 12.1 SE, CO US
# 4     -104.61     38.27               7001         PUEBLO 1.1 ENE, CO US
# 5     -104.61     38.27               7001         PUEBLO 1.1 ENE, CO US
# 6     -104.96     40.12               4828       LONGMONT 8.2 ESE, CO US
# 7     -104.96     40.12               4828       LONGMONT 8.2 ESE, CO US
# 8     -104.95     40.33               4828        JOHNSTOWN 2.1 W, CO US
# 9      -82.67     30.15               4595      LAKE CITY 3.4 SSW, FL US
# 10     -82.07     27.01               4937  PORT CHARLOTTE 2.9 NE, FL US
# ...

# %%
climate_lo = pd.read_csv('../dfLocation_7.csv')
lo = climate_lo[['NAME','LATITUDE','LONGITUDE']]
lo
# Out:
#                            NAME   LATITUDE  LONGITUDE
# 0           QUINCY 1.2 W, MA US  42.259033 -71.030317
# 1     PLAINVILLE 0.6 NNW, MA US  42.008300 -71.338500
# 2        FRANKLIN 1.4 SW, MA US  42.074391 -71.408504
# 3          NORFOLK 1.1 W, MA US  42.117610 -71.337902
# 4           MEDWAY 2.1 W, MA US  42.138006 -71.440061
# ...                         ...        ...        ...
# 9995   CANANDAIGUA 4.6 S, NY US  42.822000 -77.288400
# 9996  CANANDAIGUA 4.3 SE, NY US  42.840972 -77.225832
# 9997      NAPLES 1.6 WNW, NY US  42.627900 -77.428600
# 9998       GENEVA 1.2 SW, NY US  42.851220 -76.998700
# 9999   OTISVILLE 0.6 WNW, NY US  41.473000 -74.551300
#
# [10000 rows x 3 columns]

# %%
country_df_7 = pd.DataFrame()

for idx, row in tqdm(lo.iterrows(), total=lo.shape[0]):
    lat = round(row['LATITUDE'], 4)
    lng = round(row['LONGITUDE'], 4)
    df = soil_lo.loc[(soil_lo['Latitude'] == lat) & (soil_lo['Longitude'] == lng)].copy()
    df['Country'] = lo.loc[idx, 'NAME']

    if country_df_7.empty:
        country_df_7 = df
    else:
        country_df_7 = pd.concat([country_df_7, df], axis=0)

country_df_7.reset_index(drop=True, inplace=True)
country_df_7.to_csv('country_df_7.csv')
country_df_7
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#     Longitude  Latitude  Soil Mapping Unit                          Country
# 0      -71.00     42.24               4938            QUINCY 1.5 SSE, MA US
# 1      -70.63     43.88               4939            SEBAGO 2.4 ESE, ME US
# 2      -68.89     44.61               4941           FRANKFORT 0.8 W, ME US
# 3      -87.64     46.71               4978         MARQUETTE 16.0 NW, MI US
# 4      -86.47     43.50               4979           MONTAGUE 8.1 NW, MI US
# 5      -93.33     44.82               4908        BLOOMINGTON 1.0 SW, MN US
# 6      -93.33     44.82               4908        BLOOMINGTON 1.0 SW, MN US
# 7      -93.64     47.16               4691            COHASSET 5.1 S, MN US
# 8      -94.74     39.77               4728          ST. JOSEPH 4.4 E, MO US
# 9      -94.74     39.77               4728          ST. JOSEPH 4.4 E, MO US
# 10     -93.94     36.75               4592             PURDY 4.8 SSW, MO US
# ...

# %%
climate_lo = pd.read_csv('../dfLocation_8.csv')
lo = climate_lo[['NAME','LATITUDE','LONGITUDE']]
lo
# Out:
#                            NAME   LATITUDE  LONGITUDE
# 0        WARWICK 3.2 WNW, NY US  41.268357 -74.415952
# 1          MONROE 1.7 SE, NY US  41.301445 -74.166969
# 2     PORT JERVIS 0.4 SE, NY US  41.374007 -74.684483
# 3      PINE BUSH 3.4 WSW, NY US  41.587962 -74.357663
# 4           WALDEN 1.2 S, NY US  41.542690 -74.188349
# ...                         ...        ...        ...
# 9995      VICTORIA 1.3 E, TX US  28.822000 -96.961000
# 9996      VICTORIA 2.0 S, TX US  28.795720 -96.984380
# 9997        INEZ 5.3 SSW, TX US  28.804625 -96.826581
# 9998          INEZ 2.2 S, TX US  28.843042 -96.799064
# 9999          INEZ 2.9 W, TX US  28.877091 -96.842490
#
# [10000 rows x 3 columns]

# %%
soil_lo
# Out:
#            Longitude  Latitude  Soil Mapping Unit
# 0             -35.74     83.62               6998
# 1             -35.73     83.62               6998
# 2             -35.72     83.62               6998
# 3             -35.72     83.62               6998
# 4             -35.71     83.62               6998
# ...              ...       ...                ...
# 222694353     -67.30    -55.97              13406
# 222694354     -67.29    -55.97              13406
# 222694355     -67.28    -55.97              13406
# 222694356     -67.28    -55.97              13406
# 222694357     -67.27    -55.97              13406
#
# [222694358 rows x 3 columns]

# %%
country_df_8 = pd.DataFrame()

for idx, row in tqdm(lo.iterrows(), total=lo.shape[0]):
    lat = round(row['LATITUDE'], 4)
    lng = round(row['LONGITUDE'], 4)
    df = soil_lo.loc[(soil_lo['Latitude'] == lat) & (soil_lo['Longitude'] == lng)].copy()
    df['Country'] = lo.loc[idx, 'NAME']

    if country_df_8.empty:
        country_df_8 = df
    else:
        country_df_8 = pd.concat([country_df_8, df], axis=0)

country_df_8.reset_index(drop=True, inplace=True)
country_df_8.to_csv('country_df_8.csv')
country_df_8
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 6
#       4 lat = round(row['LATITUDE'], 4)
#       5 lng = round(row['LONGITUDE'], 4)
# ----> 6 df = soil_lo.loc[(soil_lo['Latitude'] == lat) & (soil_lo['Longitude'] == lng)].copy()
#       7 df['Country'] = lo.loc[idx, 'NAME']
#       9 if country_df_8.empty:
#
# File c:\Users\user\miniconda3\envs\ds_study\lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\user\miniconda3\envs\ds_study\lib\site-packages\pandas\core\arraylike.py:70, in OpsMixin.__and__(self, other)
#      68 @unpack_zerodim_and_defer("__and__")
#      69 def __and__(self, other):
# ...
